# %% [markdown]
# # PREPARING DATA

# %%
import pandas as pd
import glob
import os
import numpy as np

# Path ke folder train
folder_path = r"D:\Data Sains\dataset\comodity-price-prediction-penyisihan-arkavidia-9\iris n\Harga Bahan Pangan\train"
output_file = "merged_commodities.csv"

# Ambil semua file CSV dalam folder train
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

# Dictionary untuk menyimpan rentang harga tiap komoditas
price_ranges = {}

# Identifikasi rentang harga dari setiap komoditas
for file in csv_files:
    # Ambil nama komoditas dari nama file
    commodity_name = os.path.splitext(os.path.basename(file))[0]
    
    # Baca CSV
    df = pd.read_csv(file)
    
    # Konversi semua kolom kecuali tanggal ke numerik
    df.iloc[:, 1:] = df.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')
    
    # Ambil hanya nilai harga tanpa tanggal
    harga_values = df.iloc[:, 1:].values.flatten()
    
    # Buang NaN agar tidak mengganggu perhitungan
    harga_values = harga_values[~np.isnan(harga_values)]
    
    # Hitung rentang harga berdasarkan metode IQR (Interquartile Range)
    Q1 = np.percentile(harga_values, 25)
    Q3 = np.percentile(harga_values, 75)
    IQR = Q3 - Q1
    min_price = max(0, Q1 - 1.5 * IQR)  # Harga tidak mungkin negatif
    max_price = Q3 + 1.5 * IQR
    
    # Simpan rentang harga ke dictionary
    price_ranges[commodity_name] = (min_price, max_price)

# List untuk menyimpan DataFrame hasil transformasi
df_list = []

# Proses ulang setiap file CSV untuk menggabungkan data
for file in csv_files:
    # Ambil nama komoditas dari nama file
    commodity_name = os.path.splitext(os.path.basename(file))[0]
    
    # Baca CSV
    df = pd.read_csv(file)
    
    # Unpivot (melt) data
    df_melted = df.melt(id_vars=["Date"], var_name="provinsi", value_name="harga")
    
    # Tambahkan kolom komoditas
    df_melted["komoditas"] = commodity_name
    
    # Konversi harga ke numerik untuk memastikan konsistensi
    df_melted["harga"] = pd.to_numeric(df_melted["harga"], errors='coerce')
    
    # Handle outlier menggunakan rentang harga yang sudah dihitung
    min_price, max_price = price_ranges[commodity_name]
    df_melted.loc[(df_melted["harga"] < min_price) | (df_melted["harga"] > max_price), "harga"] = np.nan
    
    # Tambahkan kolom id
    df_melted["id"] = df_melted["komoditas"] + "/" + df_melted["provinsi"] + "/" + df_melted["Date"]
    
    # Simpan hasil
    df_list.append(df_melted)

# Gabungkan semua DataFrame
final_df = pd.concat(df_list, ignore_index=True)

# Simpan ke CSV
final_df.to_csv(output_file, index=False)

print("File gabungan berhasil dibuat:", output_file)


# Path folder test
folder_path_2 = r"D:\Data Sains\dataset\comodity-price-prediction-penyisihan-arkavidia-9\iris n\Harga Bahan Pangan\test"
output_file_2 = "test_clean.csv"

# Ambil semua file CSV dalam folder test
csv_files = glob.glob(os.path.join(folder_path_2, "*.csv"))

# List untuk menyimpan DataFrame hasil transformasi
df_list = []

# Proses setiap file CSV dan gabungkan
for file in csv_files:
    # Ambil nama komoditas dari nama file
    commodity_name = os.path.splitext(os.path.basename(file))[0]
    
    # Baca CSV
    df = pd.read_csv(file)
    
    # Unpivot (melt) data
    df_melted = df.melt(id_vars=["Date"], var_name="provinsi", value_name="harga")
    
    # Tambahkan kolom komoditas
    df_melted["komoditas"] = commodity_name
    
    # Tambahkan kolom id
    df_melted["id"] = df_melted["komoditas"] + "/" + df_melted["provinsi"] + "/" + df_melted["Date"]
    
    # Simpan hasil
    df_list.append(df_melted)

# Gabungkan semua DataFrame
final_df = pd.concat(df_list, ignore_index=True)

final_df["Date"] = pd.to_datetime(final_df["Date"], errors='coerce')

# Simpan ke CSV
final_df.to_csv(output_file_2, index=False)

print("File gabungan berhasil dibuat:", output_file_2)

submission = pd.read_csv(r"D:\Data Sains\dataset\comodity-price-prediction-penyisihan-arkavidia-9\iris n\Harga Bahan Pangan\sample_submission.csv")
# Out:
# File gabungan berhasil dibuat: merged_commodities.csv
# File gabungan berhasil dibuat: test_clean.csv

# %%
# Baca File Merge_commodities dan test
train = pd.read_csv("merged_commodities.csv")
test = pd.read_csv("test_clean.csv")
test = test.drop(columns=["harga"], errors="ignore")
test['Date'] = pd.to_datetime(test['Date'], format='%Y-%m-%d', errors='coerce')

# fill harga missing with interpolasi order 1
train["harga"] = (
    train.groupby(["komoditas", "provinsi"], group_keys=False)["harga"]
    .apply(lambda x: x.interpolate())
    .reset_index(drop=True)
)

# fill rest of missing with bfill
train["harga"] = train.groupby(["komoditas", "provinsi"])["harga"].fillna(method="ffill").fillna(method="bfill")

# save to train_clean.csv
train.to_csv("train_clean.csv")

train['Date'] = pd.to_datetime(train['Date'], format='%Y-%m-%d', errors='coerce')

# %% [markdown]
# # MODEL

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
import warnings
import os

# Abaikan warning dari ARIMA
warnings.filterwarnings("ignore")

# --- Asumsi: DataFrame train dan test sudah tersedia ---
# Contoh:
# train = pd.read_csv('data_train.csv')
# test = pd.read_csv('data_test.csv')

# Siapkan hasil submission (salinan dari test)
submission = test.copy()
submission['price'] = np.nan  # Inisialisasi kolom prediksi

# List untuk menyimpan detail MAPE tiap kombinasi (komoditas, provinsi)
mape_list = []

# Looping berdasarkan kombinasi: *komoditas* terlebih dahulu, kemudian *provinsi*
for (komoditas, provinsi), group in train.groupby(['komoditas', 'provinsi']):
    # Filter data train & test yang sesuai
    train_data = group.sort_values('Date')
    test_data = test[(test['komoditas'] == komoditas) & (test['provinsi'] == provinsi)].sort_values('Date')
    
    if len(train_data) < 30:
        print(f"Data terlalu sedikit untuk {komoditas} - {provinsi}, skip...")
        continue
    
    n = len(train_data)
    split_idx = int(n * 0.8)
    if split_idx < 1 or split_idx == n:
        print(f"Data untuk {komoditas} - {provinsi} tidak cukup untuk split 80/20.")
        continue

    # --- Evaluasi MAPE menggunakan 80/20 split ---
    train_eval = train_data.iloc[:split_idx]
    val_eval   = train_data.iloc[split_idx:]
    
    try:
        model_eval = ARIMA(train_eval['harga'], order=(5, 1, 0))
        model_fit_eval = model_eval.fit()
        forecast_eval = model_fit_eval.forecast(steps=len(val_eval))
        
        # Hitung MAPE (nilai desimal, misalnya 0.1234)
        actual = val_eval['harga'].values
        pred_eval = forecast_eval.values
        mape = np.mean(np.abs((actual - pred_eval) / actual))
        
        mape_list.append({
            'komoditas': komoditas,
            'provinsi': provinsi,
            'n_data': n,
            'mape': mape
        })
        print(f"[80/20] {komoditas} - {provinsi}: n={n}, MAPE={mape:.4f}")
    except Exception as e:
        print(f"Gagal evaluasi {komoditas} - {provinsi}: {e}")
        continue

    # --- Pelatihan model final menggunakan 100% data ---
    try:
        model_final = ARIMA(train_data['harga'], order=(5, 1, 0))
        model_fit_final = model_final.fit()
        forecast_final = model_fit_final.forecast(steps=len(test_data))
        
        # Masukkan hasil prediksi ke submission
        submission.loc[test_data.index, 'price'] = forecast_final.values
    except Exception as e:
        print(f"Gagal proses final {komoditas} - {provinsi}: {e}")
        continue

# Hapus kolom yang tidak diperlukan pada submission
submission = submission.drop(columns=['provinsi', 'komoditas', 'Date'])

# Simpan file submission ke CSV
submission.to_csv('final_arima.csv', index=False)
print("Prediksi selesai! File 'final.csv' telah dibuat 🚀")

# --- Simpan hasil MAPE ke file Excel ---
df_mape = pd.DataFrame(mape_list)
if not df_mape.empty:
    overall_avg_mape = df_mape['mape'].mean()
else:
    overall_avg_mape = None

df_overall = pd.DataFrame({
    'overall_avg_mape': [overall_avg_mape],
    'n_models': [len(df_mape)]
})

with pd.ExcelWriter('mape_results_final_arima.xlsx') as writer:
    df_mape.to_excel(writer, sheet_name='MAPE_Detail', index=False)
    df_overall.to_excel(writer, sheet_name='MAPE_Overall', index=False)

print("Hasil MAPE telah disimpan ke 'mape_results_final_arima.xlsx'.")
# Out:
# [80/20] Bawang Merah - Aceh: n=1004, MAPE=0.2767
# [80/20] Bawang Merah - Bali: n=1004, MAPE=0.2087
# [80/20] Bawang Merah - Banten: n=1004, MAPE=0.2242
# [80/20] Bawang Merah - Bengkulu: n=1004, MAPE=0.2769
# [80/20] Bawang Merah - DI Yogyakarta: n=1004, MAPE=0.3071
# [80/20] Bawang Merah - DKI Jakarta: n=1004, MAPE=0.2135
# [80/20] Bawang Merah - Gorontalo: n=1004, MAPE=0.2090
# [80/20] Bawang Merah - Jambi: n=1004, MAPE=0.2550
# [80/20] Bawang Merah - Jawa Barat: n=1004, MAPE=0.2276
# [80/20] Bawang Merah - Jawa Tengah: n=1004, MAPE=0.2638
# [80/20] Bawang Merah - Jawa Timur: n=1004, MAPE=0.2732
# [80/20] Bawang Merah - Kalimantan Barat: n=1004, MAPE=0.1484
# [80/20] Bawang Merah - Kalimantan Selatan: n=1004, MAPE=0.2199
# [80/20] Bawang Merah - Kalimantan Tengah: n=1004, MAPE=0.1999
# [80/20] Bawang Merah - Kalimantan Timur: n=1004, MAPE=0.1615
# [80/20] Bawang Merah - Kalimantan Utara: n=1004, MAPE=0.1596
# [80/20] Bawang Merah - Kepulauan Bangka Belitung: n=1004, MAPE=0.2526
# [80/20] Bawang Merah - Kepulauan Riau: n=1004, MAPE=0.0703
# [80/20] Bawang Merah - Lampung: n=1004, MAPE=0.2950
# [80/20] Bawang Merah - Maluku: n=1004, MAPE=0.1504
# [80/20] Bawang Merah - Maluku Utara: n=1004, MAPE=0.0826
# [80/20] Bawang Merah - Nusa Tenggara Barat: n=1004, MAPE=0.3597
# [80/20] Bawang Merah - Nusa Tenggara Timur: n=1004, MAPE=0.3012
# [80/20] Bawang Merah - Papua: n=1004, MAPE=0.0710
# [80/20] Bawang Merah - Papua Barat: n=1004, MAPE=0.0657
# [80/20] Bawang Merah - Riau: n=1004, MAPE=0.2514
# [80/20] Bawang Merah - Sulawesi Barat: n=1004, MAPE=0.1941
# [80/20] Bawang Merah - Sulawesi Selatan: n=1004, MAPE=0.1957
# [80/20] Bawang Merah - Sulawesi Tengah: n=1004, MAPE=0.1849
# [80/20] Bawang Merah - Sulawesi Tenggara: n=1004, MAPE=0.2042
# [80/20] Bawang Merah - Sulawesi Utara: n=1004, MAPE=0.1743
# [80/20] Bawang Merah - Sumatera Barat: n=1004, MAPE=0.3175
# [80/20] Bawang Merah - Sumatera Selatan: n=1004, MAPE=0.2816
# [80/20] Bawang Merah - Sumatera Utara: n=1004, MAPE=0.2507
# [80/20] Bawang Putih Bonggol - Aceh: n=1004, MAPE=0.0227
# [80/20] Bawang Putih Bonggol - Bali: n=1004, MAPE=0.0339
# [80/20] Bawang Putih Bonggol - Banten: n=1004, MAPE=0.0603
# [80/20] Bawang Putih Bonggol - Bengkulu: n=1004, MAPE=0.0547
# [80/20] Bawang Putih Bonggol - DI Yogyakarta: n=1004, MAPE=0.0272
# [80/20] Bawang Putih Bonggol - DKI Jakarta: n=1004, MAPE=0.0624
# [80/20] Bawang Putih Bonggol - Gorontalo: n=1004, MAPE=0.0833
# [80/20] Bawang Putih Bonggol - Jambi: n=1004, MAPE=0.0324
# [80/20] Bawang Putih Bonggol - Jawa Barat: n=1004, MAPE=0.0388
# [80/20] Bawang Putih Bonggol - Jawa Tengah: n=1004, MAPE=0.0273
# [80/20] Bawang Putih Bonggol - Jawa Timur: n=1004, MAPE=0.0284
# [80/20] Bawang Putih Bonggol - Kalimantan Barat: n=1004, MAPE=0.0638
# [80/20] Bawang Putih Bonggol - Kalimantan Selatan: n=1004, MAPE=0.0401
# [80/20] Bawang Putih Bonggol - Kalimantan Tengah: n=1004, MAPE=0.0424
# [80/20] Bawang Putih Bonggol - Kalimantan Timur: n=1004, MAPE=0.0414
# [80/20] Bawang Putih Bonggol - Kalimantan Utara: n=1004, MAPE=0.0497
# [80/20] Bawang Putih Bonggol - Kepulauan Bangka Belitung: n=1004, MAPE=0.0581
# [80/20] Bawang Putih Bonggol - Kepulauan Riau: n=1004, MAPE=0.0586
# [80/20] Bawang Putih Bonggol - Lampung: n=1004, MAPE=0.0505
# [80/20] Bawang Putih Bonggol - Maluku: n=1004, MAPE=0.0441
# [80/20] Bawang Putih Bonggol - Maluku Utara: n=1004, MAPE=0.0374
# [80/20] Bawang Putih Bonggol - Nusa Tenggara Barat: n=1004, MAPE=0.0372
# [80/20] Bawang Putih Bonggol - Nusa Tenggara Timur: n=1004, MAPE=0.0560
# [80/20] Bawang Putih Bonggol - Papua: n=1004, MAPE=0.0356
# [80/20] Bawang Putih Bonggol - Papua Barat: n=1004, MAPE=0.0379
# [80/20] Bawang Putih Bonggol - Riau: n=1004, MAPE=0.0306
# [80/20] Bawang Putih Bonggol - Sulawesi Barat: n=1004, MAPE=0.0326
# [80/20] Bawang Putih Bonggol - Sulawesi Selatan: n=1004, MAPE=0.0211
# [80/20] Bawang Putih Bonggol - Sulawesi Tengah: n=1004, MAPE=0.0437
# [80/20] Bawang Putih Bonggol - Sulawesi Tenggara: n=1004, MAPE=0.0566
# [80/20] Bawang Putih Bonggol - Sulawesi Utara: n=1004, MAPE=0.1167
# [80/20] Bawang Putih Bonggol - Sumatera Barat: n=1004, MAPE=0.0179
# [80/20] Bawang Putih Bonggol - Sumatera Selatan: n=1004, MAPE=0.0506
# [80/20] Bawang Putih Bonggol - Sumatera Utara: n=1004, MAPE=0.0273
# [80/20] Beras Medium - Aceh: n=1004, MAPE=0.0077
# [80/20] Beras Medium - Bali: n=1004, MAPE=0.0761
# [80/20] Beras Medium - Banten: n=1004, MAPE=0.1325
# [80/20] Beras Medium - Bengkulu: n=1004, MAPE=0.0334
# [80/20] Beras Medium - DI Yogyakarta: n=1004, MAPE=0.1234
# [80/20] Beras Medium - DKI Jakarta: n=1004, MAPE=0.0563
# [80/20] Beras Medium - Gorontalo: n=1004, MAPE=0.1784
# [80/20] Beras Medium - Jambi: n=1004, MAPE=0.0339
# [80/20] Beras Medium - Jawa Barat: n=1004, MAPE=0.1319
# [80/20] Beras Medium - Jawa Tengah: n=1004, MAPE=0.1139
# [80/20] Beras Medium - Jawa Timur: n=1004, MAPE=0.0290
# [80/20] Beras Medium - Kalimantan Barat: n=1004, MAPE=0.0086
# [80/20] Beras Medium - Kalimantan Selatan: n=1004, MAPE=0.0271
# [80/20] Beras Medium - Kalimantan Tengah: n=1004, MAPE=0.0256
# [80/20] Beras Medium - Kalimantan Timur: n=1004, MAPE=0.0264
# [80/20] Beras Medium - Kalimantan Utara: n=1004, MAPE=0.0140
# [80/20] Beras Medium - Kepulauan Bangka Belitung: n=1004, MAPE=0.0474
# [80/20] Beras Medium - Kepulauan Riau: n=1004, MAPE=0.0125
# [80/20] Beras Medium - Lampung: n=1004, MAPE=0.0965
# [80/20] Beras Medium - Maluku: n=1004, MAPE=0.0120
# [80/20] Beras Medium - Maluku Utara: n=1004, MAPE=0.0262
# [80/20] Beras Medium - Nusa Tenggara Barat: n=1004, MAPE=0.1024
# [80/20] Beras Medium - Nusa Tenggara Timur: n=1004, MAPE=0.1150
# [80/20] Beras Medium - Papua: n=1004, MAPE=0.0297
# [80/20] Beras Medium - Papua Barat: n=1004, MAPE=0.0221
# [80/20] Beras Medium - Riau: n=1004, MAPE=0.0168
# [80/20] Beras Medium - Sulawesi Barat: n=1004, MAPE=0.1173
# [80/20] Beras Medium - Sulawesi Selatan: n=1004, MAPE=0.0995
# [80/20] Beras Medium - Sulawesi Tengah: n=1004, MAPE=0.0842
# [80/20] Beras Medium - Sulawesi Tenggara: n=1004, MAPE=0.0801
# [80/20] Beras Medium - Sulawesi Utara: n=1004, MAPE=0.1065
# [80/20] Beras Medium - Sumatera Barat: n=1004, MAPE=0.0192
# [80/20] Beras Medium - Sumatera Selatan: n=1004, MAPE=0.0755
# [80/20] Beras Medium - Sumatera Utara: n=1004, MAPE=0.0109
# [80/20] Beras Premium - Aceh: n=1004, MAPE=0.0062
# [80/20] Beras Premium - Bali: n=1004, MAPE=0.0673
# [80/20] Beras Premium - Banten: n=1004, MAPE=0.0854
# [80/20] Beras Premium - Bengkulu: n=1004, MAPE=0.0417
# [80/20] Beras Premium - DI Yogyakarta: n=1004, MAPE=0.1047
# [80/20] Beras Premium - DKI Jakarta: n=1004, MAPE=0.0626
# [80/20] Beras Premium - Gorontalo: n=1004, MAPE=0.1487
# [80/20] Beras Premium - Jambi: n=1004, MAPE=0.0209
# [80/20] Beras Premium - Jawa Barat: n=1004, MAPE=0.0790
# [80/20] Beras Premium - Jawa Tengah: n=1004, MAPE=0.0751
# [80/20] Beras Premium - Jawa Timur: n=1004, MAPE=0.0500
# [80/20] Beras Premium - Kalimantan Barat: n=1004, MAPE=0.0110
# [80/20] Beras Premium - Kalimantan Selatan: n=1004, MAPE=0.0184
# [80/20] Beras Premium - Kalimantan Tengah: n=1004, MAPE=0.0130
# [80/20] Beras Premium - Kalimantan Timur: n=1004, MAPE=0.0282
# [80/20] Beras Premium - Kalimantan Utara: n=1004, MAPE=0.0076
# [80/20] Beras Premium - Kepulauan Bangka Belitung: n=1004, MAPE=0.0687
# [80/20] Beras Premium - Kepulauan Riau: n=1004, MAPE=0.0164
# [80/20] Beras Premium - Lampung: n=1004, MAPE=0.0790
# [80/20] Beras Premium - Maluku: n=1004, MAPE=0.0097
# [80/20] Beras Premium - Maluku Utara: n=1004, MAPE=0.0050
# [80/20] Beras Premium - Nusa Tenggara Barat: n=1004, MAPE=0.1202
# [80/20] Beras Premium - Nusa Tenggara Timur: n=1004, MAPE=0.0754
# [80/20] Beras Premium - Papua: n=1004, MAPE=0.0079
# [80/20] Beras Premium - Papua Barat: n=1004, MAPE=0.0110
# [80/20] Beras Premium - Riau: n=1004, MAPE=0.0177
# [80/20] Beras Premium - Sulawesi Barat: n=1004, MAPE=0.0841
# [80/20] Beras Premium - Sulawesi Selatan: n=1004, MAPE=0.0788
# [80/20] Beras Premium - Sulawesi Tengah: n=1004, MAPE=0.0673
# [80/20] Beras Premium - Sulawesi Tenggara: n=1004, MAPE=0.1357
# [80/20] Beras Premium - Sulawesi Utara: n=1004, MAPE=0.1071
# [80/20] Beras Premium - Sumatera Barat: n=1004, MAPE=0.0070
# [80/20] Beras Premium - Sumatera Selatan: n=1004, MAPE=0.0407
# [80/20] Beras Premium - Sumatera Utara: n=1004, MAPE=0.0073
# [80/20] Cabai Merah Keriting - Aceh: n=1004, MAPE=0.5873
# [80/20] Cabai Merah Keriting - Bali: n=1004, MAPE=0.8780
# [80/20] Cabai Merah Keriting - Banten: n=1004, MAPE=0.9187
# [80/20] Cabai Merah Keriting - Bengkulu: n=1004, MAPE=0.5710
# [80/20] Cabai Merah Keriting - DI Yogyakarta: n=1004, MAPE=0.6747
# [80/20] Cabai Merah Keriting - DKI Jakarta: n=1004, MAPE=0.8127
# [80/20] Cabai Merah Keriting - Gorontalo: n=1004, MAPE=0.2417
# [80/20] Cabai Merah Keriting - Jambi: n=1004, MAPE=1.1316
# [80/20] Cabai Merah Keriting - Jawa Barat: n=1004, MAPE=0.8204
# [80/20] Cabai Merah Keriting - Jawa Tengah: n=1004, MAPE=0.7856
# [80/20] Cabai Merah Keriting - Jawa Timur: n=1004, MAPE=0.5603
# [80/20] Cabai Merah Keriting - Kalimantan Barat: n=1004, MAPE=0.1178
# [80/20] Cabai Merah Keriting - Kalimantan Selatan: n=1004, MAPE=0.7249
# [80/20] Cabai Merah Keriting - Kalimantan Tengah: n=1004, MAPE=0.3098
# [80/20] Cabai Merah Keriting - Kalimantan Timur: n=1004, MAPE=0.3408
# [80/20] Cabai Merah Keriting - Kalimantan Utara: n=1004, MAPE=0.1572
# [80/20] Cabai Merah Keriting - Kepulauan Bangka Belitung: n=1004, MAPE=0.5515
# [80/20] Cabai Merah Keriting - Kepulauan Riau: n=1004, MAPE=0.3646
# [80/20] Cabai Merah Keriting - Lampung: n=1004, MAPE=0.8231
# [80/20] Cabai Merah Keriting - Maluku: n=1004, MAPE=0.1293
# [80/20] Cabai Merah Keriting - Maluku Utara: n=1004, MAPE=0.1737
# [80/20] Cabai Merah Keriting - Nusa Tenggara Barat: n=1004, MAPE=0.7635
# [80/20] Cabai Merah Keriting - Nusa Tenggara Timur: n=1004, MAPE=0.1210
# [80/20] Cabai Merah Keriting - Papua: n=1004, MAPE=0.2004
# [80/20] Cabai Merah Keriting - Papua Barat: n=1004, MAPE=0.1980
# [80/20] Cabai Merah Keriting - Riau: n=1004, MAPE=0.7874
# [80/20] Cabai Merah Keriting - Sulawesi Barat: n=1004, MAPE=0.6375
# [80/20] Cabai Merah Keriting - Sulawesi Selatan: n=1004, MAPE=0.6169
# [80/20] Cabai Merah Keriting - Sulawesi Tengah: n=1004, MAPE=0.1596
# [80/20] Cabai Merah Keriting - Sulawesi Tenggara: n=1004, MAPE=0.1987
# [80/20] Cabai Merah Keriting - Sulawesi Utara: n=1004, MAPE=0.3301
# [80/20] Cabai Merah Keriting - Sumatera Barat: n=1004, MAPE=0.8531
# [80/20] Cabai Merah Keriting - Sumatera Selatan: n=1004, MAPE=0.6814
# [80/20] Cabai Merah Keriting - Sumatera Utara: n=1004, MAPE=1.1123
# [80/20] Cabai Rawit Merah - Aceh: n=1004, MAPE=0.3496
# [80/20] Cabai Rawit Merah - Bali: n=1004, MAPE=0.7846
# [80/20] Cabai Rawit Merah - Banten: n=1004, MAPE=0.5782
# [80/20] Cabai Rawit Merah - Bengkulu: n=1004, MAPE=0.3387
# [80/20] Cabai Rawit Merah - DI Yogyakarta: n=1004, MAPE=0.4620
# [80/20] Cabai Rawit Merah - DKI Jakarta: n=1004, MAPE=0.4590
# [80/20] Cabai Rawit Merah - Gorontalo: n=1004, MAPE=0.2506
# [80/20] Cabai Rawit Merah - Jambi: n=1004, MAPE=0.5023
# [80/20] Cabai Rawit Merah - Jawa Barat: n=1004, MAPE=0.5628
# [80/20] Cabai Rawit Merah - Jawa Tengah: n=1004, MAPE=0.6281
# [80/20] Cabai Rawit Merah - Jawa Timur: n=1004, MAPE=0.5421
# [80/20] Cabai Rawit Merah - Kalimantan Barat: n=1004, MAPE=0.1218
# [80/20] Cabai Rawit Merah - Kalimantan Selatan: n=1004, MAPE=0.4806
# [80/20] Cabai Rawit Merah - Kalimantan Tengah: n=1004, MAPE=0.3408
# [80/20] Cabai Rawit Merah - Kalimantan Timur: n=1004, MAPE=0.4135
# [80/20] Cabai Rawit Merah - Kalimantan Utara: n=1004, MAPE=0.1802
# [80/20] Cabai Rawit Merah - Kepulauan Bangka Belitung: n=1004, MAPE=0.4131
# [80/20] Cabai Rawit Merah - Kepulauan Riau: n=1004, MAPE=0.2927
# [80/20] Cabai Rawit Merah - Lampung: n=1004, MAPE=0.3412
# [80/20] Cabai Rawit Merah - Maluku: n=1004, MAPE=0.2465
# [80/20] Cabai Rawit Merah - Maluku Utara: n=1004, MAPE=0.1127
# [80/20] Cabai Rawit Merah - Nusa Tenggara Barat: n=1004, MAPE=0.4534
# [80/20] Cabai Rawit Merah - Nusa Tenggara Timur: n=1004, MAPE=0.2117
# [80/20] Cabai Rawit Merah - Papua: n=1004, MAPE=0.3293
# [80/20] Cabai Rawit Merah - Papua Barat: n=1004, MAPE=0.1991
# [80/20] Cabai Rawit Merah - Riau: n=1004, MAPE=0.3186
# [80/20] Cabai Rawit Merah - Sulawesi Barat: n=1004, MAPE=0.1113
# [80/20] Cabai Rawit Merah - Sulawesi Selatan: n=1004, MAPE=0.2484
# [80/20] Cabai Rawit Merah - Sulawesi Tengah: n=1004, MAPE=0.1641
# [80/20] Cabai Rawit Merah - Sulawesi Tenggara: n=1004, MAPE=0.1222
# [80/20] Cabai Rawit Merah - Sulawesi Utara: n=1004, MAPE=0.2123
# [80/20] Cabai Rawit Merah - Sumatera Barat: n=1004, MAPE=0.4347
# [80/20] Cabai Rawit Merah - Sumatera Selatan: n=1004, MAPE=0.5147
# [80/20] Cabai Rawit Merah - Sumatera Utara: n=1004, MAPE=0.2849
# [80/20] Daging Ayam Ras - Aceh: n=1004, MAPE=0.0770
# [80/20] Daging Ayam Ras - Bali: n=1004, MAPE=0.0189
# [80/20] Daging Ayam Ras - Banten: n=1004, MAPE=0.0620
# [80/20] Daging Ayam Ras - Bengkulu: n=1004, MAPE=0.1211
# [80/20] Daging Ayam Ras - DI Yogyakarta: n=1004, MAPE=0.0946
# [80/20] Daging Ayam Ras - DKI Jakarta: n=1004, MAPE=0.0361
# [80/20] Daging Ayam Ras - Gorontalo: n=1004, MAPE=0.1104
# [80/20] Daging Ayam Ras - Jambi: n=1004, MAPE=0.1584
# [80/20] Daging Ayam Ras - Jawa Barat: n=1004, MAPE=0.0884
# [80/20] Daging Ayam Ras - Jawa Tengah: n=1004, MAPE=0.0681
# [80/20] Daging Ayam Ras - Jawa Timur: n=1004, MAPE=0.1122
# [80/20] Daging Ayam Ras - Kalimantan Barat: n=1004, MAPE=0.0596
# [80/20] Daging Ayam Ras - Kalimantan Selatan: n=1004, MAPE=0.0805
# [80/20] Daging Ayam Ras - Kalimantan Tengah: n=1004, MAPE=0.0740
# [80/20] Daging Ayam Ras - Kalimantan Timur: n=1004, MAPE=0.0600
# [80/20] Daging Ayam Ras - Kalimantan Utara: n=1004, MAPE=0.0399
# [80/20] Daging Ayam Ras - Kepulauan Bangka Belitung: n=1004, MAPE=0.0333
# [80/20] Daging Ayam Ras - Kepulauan Riau: n=1004, MAPE=0.0205
# [80/20] Daging Ayam Ras - Lampung: n=1004, MAPE=0.0448
# [80/20] Daging Ayam Ras - Maluku: n=1004, MAPE=0.0257
# [80/20] Daging Ayam Ras - Maluku Utara: n=1004, MAPE=0.0183
# [80/20] Daging Ayam Ras - Nusa Tenggara Barat: n=1004, MAPE=0.0483
# [80/20] Daging Ayam Ras - Nusa Tenggara Timur: n=1004, MAPE=0.0172
# [80/20] Daging Ayam Ras - Papua: n=1004, MAPE=0.0787
# [80/20] Daging Ayam Ras - Papua Barat: n=1004, MAPE=0.0420
# [80/20] Daging Ayam Ras - Riau: n=1004, MAPE=0.1631
# [80/20] Daging Ayam Ras - Sulawesi Barat: n=1004, MAPE=0.0417
# [80/20] Daging Ayam Ras - Sulawesi Selatan: n=1004, MAPE=0.1124
# [80/20] Daging Ayam Ras - Sulawesi Tengah: n=1004, MAPE=0.0682
# [80/20] Daging Ayam Ras - Sulawesi Tenggara: n=1004, MAPE=0.0727
# [80/20] Daging Ayam Ras - Sulawesi Utara: n=1004, MAPE=0.0703
# [80/20] Daging Ayam Ras - Sumatera Barat: n=1004, MAPE=0.0656
# [80/20] Daging Ayam Ras - Sumatera Selatan: n=1004, MAPE=0.1227
# [80/20] Daging Ayam Ras - Sumatera Utara: n=1004, MAPE=0.1537
# [80/20] Daging Sapi Murni - Aceh: n=1004, MAPE=0.0167
# [80/20] Daging Sapi Murni - Bali: n=1004, MAPE=0.0113
# [80/20] Daging Sapi Murni - Banten: n=1004, MAPE=0.0138
# [80/20] Daging Sapi Murni - Bengkulu: n=1004, MAPE=0.0187
# [80/20] Daging Sapi Murni - DI Yogyakarta: n=1004, MAPE=0.0080
# [80/20] Daging Sapi Murni - DKI Jakarta: n=1004, MAPE=0.0178
# [80/20] Daging Sapi Murni - Gorontalo: n=1004, MAPE=0.0058
# [80/20] Daging Sapi Murni - Jambi: n=1004, MAPE=0.0301
# [80/20] Daging Sapi Murni - Jawa Barat: n=1004, MAPE=0.0258
# [80/20] Daging Sapi Murni - Jawa Tengah: n=1004, MAPE=0.0105
# [80/20] Daging Sapi Murni - Jawa Timur: n=1004, MAPE=0.0102
# [80/20] Daging Sapi Murni - Kalimantan Barat: n=1004, MAPE=0.0064
# [80/20] Daging Sapi Murni - Kalimantan Selatan: n=1004, MAPE=0.0079
# [80/20] Daging Sapi Murni - Kalimantan Tengah: n=1004, MAPE=0.0086
# [80/20] Daging Sapi Murni - Kalimantan Timur: n=1004, MAPE=0.0094
# [80/20] Daging Sapi Murni - Kalimantan Utara: n=1004, MAPE=0.0375
# [80/20] Daging Sapi Murni - Kepulauan Bangka Belitung: n=1004, MAPE=0.0083
# [80/20] Daging Sapi Murni - Kepulauan Riau: n=1004, MAPE=0.0142
# [80/20] Daging Sapi Murni - Lampung: n=1004, MAPE=0.0127
# [80/20] Daging Sapi Murni - Maluku: n=1004, MAPE=0.0183
# [80/20] Daging Sapi Murni - Maluku Utara: n=1004, MAPE=0.0289
# [80/20] Daging Sapi Murni - Nusa Tenggara Barat: n=1004, MAPE=0.0095
# [80/20] Daging Sapi Murni - Nusa Tenggara Timur: n=1004, MAPE=0.0082
# [80/20] Daging Sapi Murni - Papua: n=1004, MAPE=0.0120
# [80/20] Daging Sapi Murni - Papua Barat: n=1004, MAPE=0.0299
# [80/20] Daging Sapi Murni - Riau: n=1004, MAPE=0.0174
# [80/20] Daging Sapi Murni - Sulawesi Barat: n=1004, MAPE=0.0063
# [80/20] Daging Sapi Murni - Sulawesi Selatan: n=1004, MAPE=0.0043
# [80/20] Daging Sapi Murni - Sulawesi Tengah: n=1004, MAPE=0.0133
# [80/20] Daging Sapi Murni - Sulawesi Tenggara: n=1004, MAPE=0.0067
# [80/20] Daging Sapi Murni - Sulawesi Utara: n=1004, MAPE=0.0121
# [80/20] Daging Sapi Murni - Sumatera Barat: n=1004, MAPE=0.0166
# [80/20] Daging Sapi Murni - Sumatera Selatan: n=1004, MAPE=0.0101
# [80/20] Daging Sapi Murni - Sumatera Utara: n=1004, MAPE=0.0128
# [80/20] Gula Konsumsi - Aceh: n=1004, MAPE=0.0126
# [80/20] Gula Konsumsi - Bali: n=1004, MAPE=0.0090
# [80/20] Gula Konsumsi - Banten: n=1004, MAPE=0.0416
# [80/20] Gula Konsumsi - Bengkulu: n=1004, MAPE=0.0227
# [80/20] Gula Konsumsi - DI Yogyakarta: n=1004, MAPE=0.0224
# [80/20] Gula Konsumsi - DKI Jakarta: n=1004, MAPE=0.0985
# [80/20] Gula Konsumsi - Gorontalo: n=1004, MAPE=0.0269
# [80/20] Gula Konsumsi - Jambi: n=1004, MAPE=0.0204
# [80/20] Gula Konsumsi - Jawa Barat: n=1004, MAPE=0.0265
# [80/20] Gula Konsumsi - Jawa Tengah: n=1004, MAPE=0.0142
# [80/20] Gula Konsumsi - Jawa Timur: n=1004, MAPE=0.0178
# [80/20] Gula Konsumsi - Kalimantan Barat: n=1004, MAPE=0.0153
# [80/20] Gula Konsumsi - Kalimantan Selatan: n=1004, MAPE=0.0188
# [80/20] Gula Konsumsi - Kalimantan Tengah: n=1004, MAPE=0.0151
# [80/20] Gula Konsumsi - Kalimantan Timur: n=1004, MAPE=0.0214
# [80/20] Gula Konsumsi - Kalimantan Utara: n=1004, MAPE=0.0087
# [80/20] Gula Konsumsi - Kepulauan Bangka Belitung: n=1004, MAPE=0.0099
# [80/20] Gula Konsumsi - Kepulauan Riau: n=1004, MAPE=0.0145
# [80/20] Gula Konsumsi - Lampung: n=1004, MAPE=0.0224
# [80/20] Gula Konsumsi - Maluku: n=1004, MAPE=0.0175
# [80/20] Gula Konsumsi - Maluku Utara: n=1004, MAPE=0.0163
# [80/20] Gula Konsumsi - Nusa Tenggara Barat: n=1004, MAPE=0.0133
# [80/20] Gula Konsumsi - Nusa Tenggara Timur: n=1004, MAPE=0.0220
# [80/20] Gula Konsumsi - Papua: n=1004, MAPE=0.0320
# [80/20] Gula Konsumsi - Papua Barat: n=1004, MAPE=0.0524
# [80/20] Gula Konsumsi - Riau: n=1004, MAPE=0.0141
# [80/20] Gula Konsumsi - Sulawesi Barat: n=1004, MAPE=0.0128
# [80/20] Gula Konsumsi - Sulawesi Selatan: n=1004, MAPE=0.0113
# [80/20] Gula Konsumsi - Sulawesi Tengah: n=1004, MAPE=0.0091
# [80/20] Gula Konsumsi - Sulawesi Tenggara: n=1004, MAPE=0.0237
# [80/20] Gula Konsumsi - Sulawesi Utara: n=1004, MAPE=0.0166
# [80/20] Gula Konsumsi - Sumatera Barat: n=1004, MAPE=0.0180
# [80/20] Gula Konsumsi - Sumatera Selatan: n=1004, MAPE=0.0254
# [80/20] Gula Konsumsi - Sumatera Utara: n=1004, MAPE=0.0086
# [80/20] Minyak Goreng Curah - Aceh: n=1004, MAPE=0.0186
# [80/20] Minyak Goreng Curah - Bali: n=1004, MAPE=0.0428
# [80/20] Minyak Goreng Curah - Banten: n=1004, MAPE=0.0381
# [80/20] Minyak Goreng Curah - Bengkulu: n=1004, MAPE=0.0088
# [80/20] Minyak Goreng Curah - DI Yogyakarta: n=1004, MAPE=0.0400
# [80/20] Minyak Goreng Curah - DKI Jakarta: n=1004, MAPE=0.0478
# [80/20] Minyak Goreng Curah - Gorontalo: n=1004, MAPE=0.0855
# [80/20] Minyak Goreng Curah - Jambi: n=1004, MAPE=0.0219
# [80/20] Minyak Goreng Curah - Jawa Barat: n=1004, MAPE=0.0479
# [80/20] Minyak Goreng Curah - Jawa Tengah: n=1004, MAPE=0.0381
# [80/20] Minyak Goreng Curah - Jawa Timur: n=1004, MAPE=0.0352
# [80/20] Minyak Goreng Curah - Kalimantan Barat: n=1004, MAPE=0.0204
# [80/20] Minyak Goreng Curah - Kalimantan Selatan: n=1004, MAPE=0.0381
# [80/20] Minyak Goreng Curah - Kalimantan Tengah: n=1004, MAPE=0.0110
# [80/20] Minyak Goreng Curah - Kalimantan Timur: n=1004, MAPE=0.0249
# [80/20] Minyak Goreng Curah - Kalimantan Utara: n=1004, MAPE=0.0364
# [80/20] Minyak Goreng Curah - Kepulauan Bangka Belitung: n=1004, MAPE=0.0213
# [80/20] Minyak Goreng Curah - Kepulauan Riau: n=1004, MAPE=0.0233
# [80/20] Minyak Goreng Curah - Lampung: n=1004, MAPE=0.0363
# [80/20] Minyak Goreng Curah - Maluku: n=1004, MAPE=0.0690
# [80/20] Minyak Goreng Curah - Maluku Utara: n=1004, MAPE=0.0793
# [80/20] Minyak Goreng Curah - Nusa Tenggara Barat: n=1004, MAPE=0.0139
# [80/20] Minyak Goreng Curah - Nusa Tenggara Timur: n=1004, MAPE=0.0288
# [80/20] Minyak Goreng Curah - Papua: n=1004, MAPE=0.0201
# [80/20] Minyak Goreng Curah - Papua Barat: n=1004, MAPE=0.0237
# [80/20] Minyak Goreng Curah - Riau: n=1004, MAPE=0.0148
# [80/20] Minyak Goreng Curah - Sulawesi Barat: n=1004, MAPE=0.0193
# [80/20] Minyak Goreng Curah - Sulawesi Selatan: n=1004, MAPE=0.0230
# [80/20] Minyak Goreng Curah - Sulawesi Tengah: n=1004, MAPE=0.0136
# [80/20] Minyak Goreng Curah - Sulawesi Tenggara: n=1004, MAPE=0.0177
# [80/20] Minyak Goreng Curah - Sulawesi Utara: n=1004, MAPE=0.0202
# [80/20] Minyak Goreng Curah - Sumatera Barat: n=1004, MAPE=0.0074
# [80/20] Minyak Goreng Curah - Sumatera Selatan: n=1004, MAPE=0.0089
# [80/20] Minyak Goreng Curah - Sumatera Utara: n=1004, MAPE=0.0339
# [80/20] Minyak Goreng Kemasan Sederhana - Aceh: n=1004, MAPE=0.0139
# [80/20] Minyak Goreng Kemasan Sederhana - Bali: n=1004, MAPE=0.0324
# [80/20] Minyak Goreng Kemasan Sederhana - Banten: n=1004, MAPE=0.0537
# [80/20] Minyak Goreng Kemasan Sederhana - Bengkulu: n=1004, MAPE=0.0245
# [80/20] Minyak Goreng Kemasan Sederhana - DI Yogyakarta: n=1004, MAPE=0.0140
# [80/20] Minyak Goreng Kemasan Sederhana - DKI Jakarta: n=1004, MAPE=0.0197
# [80/20] Minyak Goreng Kemasan Sederhana - Gorontalo: n=1004, MAPE=0.0207
# [80/20] Minyak Goreng Kemasan Sederhana - Jambi: n=1004, MAPE=0.0225
# [80/20] Minyak Goreng Kemasan Sederhana - Jawa Barat: n=1004, MAPE=0.0101
# [80/20] Minyak Goreng Kemasan Sederhana - Jawa Tengah: n=1004, MAPE=0.0192
# [80/20] Minyak Goreng Kemasan Sederhana - Jawa Timur: n=1004, MAPE=0.0219
# [80/20] Minyak Goreng Kemasan Sederhana - Kalimantan Barat: n=1004, MAPE=0.0106
# [80/20] Minyak Goreng Kemasan Sederhana - Kalimantan Selatan: n=1004, MAPE=0.0176
# [80/20] Minyak Goreng Kemasan Sederhana - Kalimantan Tengah: n=1004, MAPE=0.0117
# [80/20] Minyak Goreng Kemasan Sederhana - Kalimantan Timur: n=1004, MAPE=0.0189
# [80/20] Minyak Goreng Kemasan Sederhana - Kalimantan Utara: n=1004, MAPE=0.0194
# [80/20] Minyak Goreng Kemasan Sederhana - Kepulauan Bangka Belitung: n=1004, MAPE=0.0218
# [80/20] Minyak Goreng Kemasan Sederhana - Kepulauan Riau: n=1004, MAPE=0.0219
# [80/20] Minyak Goreng Kemasan Sederhana - Lampung: n=1004, MAPE=0.0143
# [80/20] Minyak Goreng Kemasan Sederhana - Maluku: n=1004, MAPE=0.0176
# [80/20] Minyak Goreng Kemasan Sederhana - Maluku Utara: n=1004, MAPE=0.0153
# [80/20] Minyak Goreng Kemasan Sederhana - Nusa Tenggara Barat: n=1004, MAPE=0.0324
# [80/20] Minyak Goreng Kemasan Sederhana - Nusa Tenggara Timur: n=1004, MAPE=0.0101
# [80/20] Minyak Goreng Kemasan Sederhana - Papua: n=1004, MAPE=0.0185
# [80/20] Minyak Goreng Kemasan Sederhana - Papua Barat: n=1004, MAPE=0.0310
# [80/20] Minyak Goreng Kemasan Sederhana - Riau: n=1004, MAPE=0.0139
# [80/20] Minyak Goreng Kemasan Sederhana - Sulawesi Barat: n=1004, MAPE=0.0138
# [80/20] Minyak Goreng Kemasan Sederhana - Sulawesi Selatan: n=1004, MAPE=0.0255
# [80/20] Minyak Goreng Kemasan Sederhana - Sulawesi Tengah: n=1004, MAPE=0.0234
# [80/20] Minyak Goreng Kemasan Sederhana - Sulawesi Tenggara: n=1004, MAPE=0.0203
# [80/20] Minyak Goreng Kemasan Sederhana - Sulawesi Utara: n=1004, MAPE=0.0097
# [80/20] Minyak Goreng Kemasan Sederhana - Sumatera Barat: n=1004, MAPE=0.0138
# [80/20] Minyak Goreng Kemasan Sederhana - Sumatera Selatan: n=1004, MAPE=0.0212
# [80/20] Minyak Goreng Kemasan Sederhana - Sumatera Utara: n=1004, MAPE=0.0281
# [80/20] Telur Ayam Ras - Aceh: n=1004, MAPE=0.0651
# [80/20] Telur Ayam Ras - Bali: n=1004, MAPE=0.0461
# [80/20] Telur Ayam Ras - Banten: n=1004, MAPE=0.0974
# [80/20] Telur Ayam Ras - Bengkulu: n=1004, MAPE=0.0247
# [80/20] Telur Ayam Ras - DI Yogyakarta: n=1004, MAPE=0.1490
# [80/20] Telur Ayam Ras - DKI Jakarta: n=1004, MAPE=0.0987
# [80/20] Telur Ayam Ras - Gorontalo: n=1004, MAPE=0.1372
# [80/20] Telur Ayam Ras - Jambi: n=1004, MAPE=0.0312
# [80/20] Telur Ayam Ras - Jawa Barat: n=1004, MAPE=0.1616
# [80/20] Telur Ayam Ras - Jawa Tengah: n=1004, MAPE=0.1374
# [80/20] Telur Ayam Ras - Jawa Timur: n=1004, MAPE=0.1573
# [80/20] Telur Ayam Ras - Kalimantan Barat: n=1004, MAPE=0.0953
# [80/20] Telur Ayam Ras - Kalimantan Selatan: n=1004, MAPE=0.0857
# [80/20] Telur Ayam Ras - Kalimantan Tengah: n=1004, MAPE=0.0357
# [80/20] Telur Ayam Ras - Kalimantan Timur: n=1004, MAPE=0.0853
# [80/20] Telur Ayam Ras - Kalimantan Utara: n=1004, MAPE=0.0676
# [80/20] Telur Ayam Ras - Kepulauan Bangka Belitung: n=1004, MAPE=0.0343
# [80/20] Telur Ayam Ras - Kepulauan Riau: n=1004, MAPE=0.0457
# [80/20] Telur Ayam Ras - Lampung: n=1004, MAPE=0.0741
# [80/20] Telur Ayam Ras - Maluku: n=1004, MAPE=0.0273
# [80/20] Telur Ayam Ras - Maluku Utara: n=1004, MAPE=0.0329
# [80/20] Telur Ayam Ras - Nusa Tenggara Barat: n=1004, MAPE=0.0676
# [80/20] Telur Ayam Ras - Nusa Tenggara Timur: n=1004, MAPE=0.0429
# [80/20] Telur Ayam Ras - Papua: n=1004, MAPE=0.0147
# [80/20] Telur Ayam Ras - Papua Barat: n=1004, MAPE=0.0113
# [80/20] Telur Ayam Ras - Riau: n=1004, MAPE=0.0203
# [80/20] Telur Ayam Ras - Sulawesi Barat: n=1004, MAPE=0.1110
# [80/20] Telur Ayam Ras - Sulawesi Selatan: n=1004, MAPE=0.1289
# [80/20] Telur Ayam Ras - Sulawesi Tengah: n=1004, MAPE=0.0692
# [80/20] Telur Ayam Ras - Sulawesi Tenggara: n=1004, MAPE=0.1323
# [80/20] Telur Ayam Ras - Sulawesi Utara: n=1004, MAPE=0.0678
# [80/20] Telur Ayam Ras - Sumatera Barat: n=1004, MAPE=0.0298
# [80/20] Telur Ayam Ras - Sumatera Selatan: n=1004, MAPE=0.1028
# [80/20] Telur Ayam Ras - Sumatera Utara: n=1004, MAPE=0.0230
# [80/20] Tepung Terigu (Curah) - Aceh: n=1004, MAPE=0.0111
# [80/20] Tepung Terigu (Curah) - Bali: n=1004, MAPE=0.1045
# [80/20] Tepung Terigu (Curah) - Banten: n=1004, MAPE=0.0098
# [80/20] Tepung Terigu (Curah) - Bengkulu: n=1004, MAPE=0.0134
# [80/20] Tepung Terigu (Curah) - DI Yogyakarta: n=1004, MAPE=0.0558
# [80/20] Tepung Terigu (Curah) - DKI Jakarta: n=1004, MAPE=0.0108
# [80/20] Tepung Terigu (Curah) - Gorontalo: n=1004, MAPE=0.0257
# [80/20] Tepung Terigu (Curah) - Jambi: n=1004, MAPE=0.0100
# [80/20] Tepung Terigu (Curah) - Jawa Barat: n=1004, MAPE=0.0138
# [80/20] Tepung Terigu (Curah) - Jawa Tengah: n=1004, MAPE=0.0316
# [80/20] Tepung Terigu (Curah) - Jawa Timur: n=1004, MAPE=0.0207
# [80/20] Tepung Terigu (Curah) - Kalimantan Barat: n=1004, MAPE=0.0109
# [80/20] Tepung Terigu (Curah) - Kalimantan Selatan: n=1004, MAPE=0.0090
# [80/20] Tepung Terigu (Curah) - Kalimantan Tengah: n=1004, MAPE=0.0333
# [80/20] Tepung Terigu (Curah) - Kalimantan Timur: n=1004, MAPE=0.0369
# [80/20] Tepung Terigu (Curah) - Kalimantan Utara: n=1004, MAPE=0.0279
# [80/20] Tepung Terigu (Curah) - Kepulauan Bangka Belitung: n=1004, MAPE=0.0271
# [80/20] Tepung Terigu (Curah) - Kepulauan Riau: n=1004, MAPE=0.0296
# [80/20] Tepung Terigu (Curah) - Lampung: n=1004, MAPE=0.0138
# [80/20] Tepung Terigu (Curah) - Maluku: n=1004, MAPE=0.0283
# [80/20] Tepung Terigu (Curah) - Maluku Utara: n=1004, MAPE=0.0298
# [80/20] Tepung Terigu (Curah) - Nusa Tenggara Barat: n=1004, MAPE=0.0100
# [80/20] Tepung Terigu (Curah) - Nusa Tenggara Timur: n=1004, MAPE=0.0345
# [80/20] Tepung Terigu (Curah) - Papua: n=1004, MAPE=0.0063
# [80/20] Tepung Terigu (Curah) - Papua Barat: n=1004, MAPE=0.0189
# [80/20] Tepung Terigu (Curah) - Riau: n=1004, MAPE=0.0420
# [80/20] Tepung Terigu (Curah) - Sulawesi Barat: n=1004, MAPE=0.0188
# [80/20] Tepung Terigu (Curah) - Sulawesi Selatan: n=1004, MAPE=0.0104
# [80/20] Tepung Terigu (Curah) - Sulawesi Tengah: n=1004, MAPE=0.0195
# [80/20] Tepung Terigu (Curah) - Sulawesi Tenggara: n=1004, MAPE=0.0356
# [80/20] Tepung Terigu (Curah) - Sulawesi Utara: n=1004, MAPE=0.0219
# [80/20] Tepung Terigu (Curah) - Sumatera Barat: n=1004, MAPE=0.0326
# [80/20] Tepung Terigu (Curah) - Sumatera Selatan: n=1004, MAPE=0.0360
# [80/20] Tepung Terigu (Curah) - Sumatera Utara: n=1004, MAPE=0.0084
# Prediksi selesai! File 'final.csv' telah dibuat 🚀
# Hasil MAPE telah disimpan ke 'mape_results_final_arima.xlsx'.

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.metrics import mean_absolute_percentage_error
import warnings

# Abaikan warning yang tidak perlu
warnings.filterwarnings("ignore")

# --- Asumsi: DataFrame train dan test sudah tersedia ---
# Contoh:
# train = pd.read_csv('data_train.csv')
# test = pd.read_csv('data_test.csv')

# Siapkan hasil submission (salinan dari test)
submission = test.copy()
submission['price'] = np.nan  # Inisialisasi kolom prediksi

# List untuk menyimpan detail MAPE tiap kombinasi (komoditas, provinsi)
mape_list = []

# Looping berdasarkan kombinasi: *komoditas* terlebih dahulu, kemudian *provinsi*
for (komoditas, provinsi), group in train.groupby(['komoditas', 'provinsi']):
    # Filter data train & test yang sesuai
    train_data = group.sort_values('Date')
    test_data = test[(test['komoditas'] == komoditas) & (test['provinsi'] == provinsi)].sort_values('Date')
    
    if len(train_data) < 30:
        print(f"Data terlalu sedikit untuk {komoditas} - {provinsi}, skip...")
        continue
    
    n = len(train_data)
    split_idx = int(n * 0.8)
    if split_idx < 1 or split_idx == n:
        print(f"Data untuk {komoditas} - {provinsi} tidak cukup untuk split 80/20.")
        continue

    # --- Evaluasi MAPE menggunakan 80/20 split ---
    train_eval = train_data.iloc[:split_idx]
    val_eval   = train_data.iloc[split_idx:]
    
    try:
        # Feature & Target
        X_train = np.arange(len(train_eval)).reshape(-1, 1)
        y_train = train_eval['harga'].values
        X_val = np.arange(len(train_eval), len(train_eval) + len(val_eval)).reshape(-1, 1)
        y_val = val_eval['harga'].values
        
        # Train model
        model_eval = xgb.XGBRegressor(n_estimators=200, learning_rate=0.05, max_depth=5, random_state=42)
        model_eval.fit(X_train, y_train)
        forecast_eval = model_eval.predict(X_val)
        
        # Hitung MAPE
        mape = mean_absolute_percentage_error(y_val, forecast_eval)
        mape_list.append({'komoditas': komoditas, 'provinsi': provinsi, 'n_data': n, 'mape': mape})
        print(f"[80/20] {komoditas} - {provinsi}: n={n}, MAPE={mape:.4f}")
    except Exception as e:
        print(f"Gagal evaluasi {komoditas} - {provinsi}: {e}")
        continue

    # --- Pelatihan model final menggunakan 100% data ---
    try:
        X_full = np.arange(len(train_data)).reshape(-1, 1)
        y_full = train_data['harga'].values
        X_test = np.arange(len(train_data), len(train_data) + len(test_data)).reshape(-1, 1)
        
        model_final = xgb.XGBRegressor(n_estimators=200, learning_rate=0.05, max_depth=5, random_state=42)
        model_final.fit(X_full, y_full)
        forecast_final = model_final.predict(X_test)
        
        # Masukkan hasil prediksi ke submission
        submission.loc[test_data.index, 'price'] = forecast_final
    except Exception as e:
        print(f"Gagal proses final {komoditas} - {provinsi}: {e}")
        continue

# Hapus kolom yang tidak diperlukan pada submission
submission = submission.drop(columns=['provinsi', 'komoditas', 'Date'])

# Simpan file submission ke CSV
submission.to_csv('final_xgb.csv', index=False)
print("Prediksi selesai! File 'final_xgb.csv' telah dibuat 🚀")

# --- Simpan hasil MAPE ke file Excel ---
df_mape = pd.DataFrame(mape_list)
if not df_mape.empty:
    overall_avg_mape = df_mape['mape'].mean()
else:
    overall_avg_mape = None

df_overall = pd.DataFrame({'overall_avg_mape': [overall_avg_mape], 'n_models': [len(df_mape)]})

with pd.ExcelWriter('mape_results_final_xgb.xlsx') as writer:
    df_mape.to_excel(writer, sheet_name='MAPE_Detail', index=False)
    df_overall.to_excel(writer, sheet_name='MAPE_Overall', index=False)

print("Hasil MAPE telah disimpan ke 'mape_results_final_xgb.xlsx'.")
# Out:
# [80/20] Bawang Merah - Aceh: n=1004, MAPE=0.2752
# [80/20] Bawang Merah - Bali: n=1004, MAPE=0.2121
# [80/20] Bawang Merah - Banten: n=1004, MAPE=0.2242
# [80/20] Bawang Merah - Bengkulu: n=1004, MAPE=0.2748
# [80/20] Bawang Merah - DI Yogyakarta: n=1004, MAPE=0.3116
# [80/20] Bawang Merah - DKI Jakarta: n=1004, MAPE=0.2154
# [80/20] Bawang Merah - Gorontalo: n=1004, MAPE=0.2088
# [80/20] Bawang Merah - Jambi: n=1004, MAPE=0.2574
# [80/20] Bawang Merah - Jawa Barat: n=1004, MAPE=0.2255
# [80/20] Bawang Merah - Jawa Tengah: n=1004, MAPE=0.2587
# [80/20] Bawang Merah - Jawa Timur: n=1004, MAPE=0.2725
# [80/20] Bawang Merah - Kalimantan Barat: n=1004, MAPE=0.1490
# [80/20] Bawang Merah - Kalimantan Selatan: n=1004, MAPE=0.2192
# [80/20] Bawang Merah - Kalimantan Tengah: n=1004, MAPE=0.1993
# [80/20] Bawang Merah - Kalimantan Timur: n=1004, MAPE=0.1616
# [80/20] Bawang Merah - Kalimantan Utara: n=1004, MAPE=0.1596
# [80/20] Bawang Merah - Kepulauan Bangka Belitung: n=1004, MAPE=0.2506
# [80/20] Bawang Merah - Kepulauan Riau: n=1004, MAPE=0.0643
# [80/20] Bawang Merah - Lampung: n=1004, MAPE=0.2926
# [80/20] Bawang Merah - Maluku: n=1004, MAPE=0.1485
# [80/20] Bawang Merah - Maluku Utara: n=1004, MAPE=0.0828
# [80/20] Bawang Merah - Nusa Tenggara Barat: n=1004, MAPE=0.3324
# [80/20] Bawang Merah - Nusa Tenggara Timur: n=1004, MAPE=0.3005
# [80/20] Bawang Merah - Papua: n=1004, MAPE=0.0709
# [80/20] Bawang Merah - Papua Barat: n=1004, MAPE=0.0678
# [80/20] Bawang Merah - Riau: n=1004, MAPE=0.2486
# [80/20] Bawang Merah - Sulawesi Barat: n=1004, MAPE=0.1940
# [80/20] Bawang Merah - Sulawesi Selatan: n=1004, MAPE=0.1958
# [80/20] Bawang Merah - Sulawesi Tengah: n=1004, MAPE=0.1853
# [80/20] Bawang Merah - Sulawesi Tenggara: n=1004, MAPE=0.2059
# [80/20] Bawang Merah - Sulawesi Utara: n=1004, MAPE=0.1767
# [80/20] Bawang Merah - Sumatera Barat: n=1004, MAPE=0.2936
# [80/20] Bawang Merah - Sumatera Selatan: n=1004, MAPE=0.2887
# [80/20] Bawang Merah - Sumatera Utara: n=1004, MAPE=0.2451
# [80/20] Bawang Putih Bonggol - Aceh: n=1004, MAPE=0.0228
# [80/20] Bawang Putih Bonggol - Bali: n=1004, MAPE=0.0319
# [80/20] Bawang Putih Bonggol - Banten: n=1004, MAPE=0.0586
# [80/20] Bawang Putih Bonggol - Bengkulu: n=1004, MAPE=0.0549
# [80/20] Bawang Putih Bonggol - DI Yogyakarta: n=1004, MAPE=0.0305
# [80/20] Bawang Putih Bonggol - DKI Jakarta: n=1004, MAPE=0.0613
# [80/20] Bawang Putih Bonggol - Gorontalo: n=1004, MAPE=0.0743
# [80/20] Bawang Putih Bonggol - Jambi: n=1004, MAPE=0.0464
# [80/20] Bawang Putih Bonggol - Jawa Barat: n=1004, MAPE=0.0417
# [80/20] Bawang Putih Bonggol - Jawa Tengah: n=1004, MAPE=0.0381
# [80/20] Bawang Putih Bonggol - Jawa Timur: n=1004, MAPE=0.0270
# [80/20] Bawang Putih Bonggol - Kalimantan Barat: n=1004, MAPE=0.0658
# [80/20] Bawang Putih Bonggol - Kalimantan Selatan: n=1004, MAPE=0.0352
# [80/20] Bawang Putih Bonggol - Kalimantan Tengah: n=1004, MAPE=0.0472
# [80/20] Bawang Putih Bonggol - Kalimantan Timur: n=1004, MAPE=0.0430
# [80/20] Bawang Putih Bonggol - Kalimantan Utara: n=1004, MAPE=0.0536
# [80/20] Bawang Putih Bonggol - Kepulauan Bangka Belitung: n=1004, MAPE=0.0598
# [80/20] Bawang Putih Bonggol - Kepulauan Riau: n=1004, MAPE=0.0551
# [80/20] Bawang Putih Bonggol - Lampung: n=1004, MAPE=0.0547
# [80/20] Bawang Putih Bonggol - Maluku: n=1004, MAPE=0.0451
# [80/20] Bawang Putih Bonggol - Maluku Utara: n=1004, MAPE=0.0362
# [80/20] Bawang Putih Bonggol - Nusa Tenggara Barat: n=1004, MAPE=0.0390
# [80/20] Bawang Putih Bonggol - Nusa Tenggara Timur: n=1004, MAPE=0.0566
# [80/20] Bawang Putih Bonggol - Papua: n=1004, MAPE=0.0362
# [80/20] Bawang Putih Bonggol - Papua Barat: n=1004, MAPE=0.0382
# [80/20] Bawang Putih Bonggol - Riau: n=1004, MAPE=0.0335
# [80/20] Bawang Putih Bonggol - Sulawesi Barat: n=1004, MAPE=0.0305
# [80/20] Bawang Putih Bonggol - Sulawesi Selatan: n=1004, MAPE=0.0211
# [80/20] Bawang Putih Bonggol - Sulawesi Tengah: n=1004, MAPE=0.0459
# [80/20] Bawang Putih Bonggol - Sulawesi Tenggara: n=1004, MAPE=0.0563
# [80/20] Bawang Putih Bonggol - Sulawesi Utara: n=1004, MAPE=0.1263
# [80/20] Bawang Putih Bonggol - Sumatera Barat: n=1004, MAPE=0.0225
# [80/20] Bawang Putih Bonggol - Sumatera Selatan: n=1004, MAPE=0.0509
# [80/20] Bawang Putih Bonggol - Sumatera Utara: n=1004, MAPE=0.0290
# [80/20] Beras Medium - Aceh: n=1004, MAPE=0.0078
# [80/20] Beras Medium - Bali: n=1004, MAPE=0.0757
# [80/20] Beras Medium - Banten: n=1004, MAPE=0.1355
# [80/20] Beras Medium - Bengkulu: n=1004, MAPE=0.0359
# [80/20] Beras Medium - DI Yogyakarta: n=1004, MAPE=0.1324
# [80/20] Beras Medium - DKI Jakarta: n=1004, MAPE=0.0494
# [80/20] Beras Medium - Gorontalo: n=1004, MAPE=0.1617
# [80/20] Beras Medium - Jambi: n=1004, MAPE=0.0330
# [80/20] Beras Medium - Jawa Barat: n=1004, MAPE=0.1245
# [80/20] Beras Medium - Jawa Tengah: n=1004, MAPE=0.1137
# [80/20] Beras Medium - Jawa Timur: n=1004, MAPE=0.0315
# [80/20] Beras Medium - Kalimantan Barat: n=1004, MAPE=0.0085
# [80/20] Beras Medium - Kalimantan Selatan: n=1004, MAPE=0.0277
# [80/20] Beras Medium - Kalimantan Tengah: n=1004, MAPE=0.0275
# [80/20] Beras Medium - Kalimantan Timur: n=1004, MAPE=0.0254
# [80/20] Beras Medium - Kalimantan Utara: n=1004, MAPE=0.0160
# [80/20] Beras Medium - Kepulauan Bangka Belitung: n=1004, MAPE=0.0531
# [80/20] Beras Medium - Kepulauan Riau: n=1004, MAPE=0.0125
# [80/20] Beras Medium - Lampung: n=1004, MAPE=0.1055
# [80/20] Beras Medium - Maluku: n=1004, MAPE=0.0148
# [80/20] Beras Medium - Maluku Utara: n=1004, MAPE=0.0269
# [80/20] Beras Medium - Nusa Tenggara Barat: n=1004, MAPE=0.1033
# [80/20] Beras Medium - Nusa Tenggara Timur: n=1004, MAPE=0.1123
# [80/20] Beras Medium - Papua: n=1004, MAPE=0.0302
# [80/20] Beras Medium - Papua Barat: n=1004, MAPE=0.0217
# [80/20] Beras Medium - Riau: n=1004, MAPE=0.0164
# [80/20] Beras Medium - Sulawesi Barat: n=1004, MAPE=0.1173
# [80/20] Beras Medium - Sulawesi Selatan: n=1004, MAPE=0.1028
# [80/20] Beras Medium - Sulawesi Tengah: n=1004, MAPE=0.0823
# [80/20] Beras Medium - Sulawesi Tenggara: n=1004, MAPE=0.0677
# [80/20] Beras Medium - Sulawesi Utara: n=1004, MAPE=0.1002
# [80/20] Beras Medium - Sumatera Barat: n=1004, MAPE=0.0197
# [80/20] Beras Medium - Sumatera Selatan: n=1004, MAPE=0.0753
# [80/20] Beras Medium - Sumatera Utara: n=1004, MAPE=0.0108
# [80/20] Beras Premium - Aceh: n=1004, MAPE=0.0064
# [80/20] Beras Premium - Bali: n=1004, MAPE=0.0612
# [80/20] Beras Premium - Banten: n=1004, MAPE=0.0796
# [80/20] Beras Premium - Bengkulu: n=1004, MAPE=0.0366
# [80/20] Beras Premium - DI Yogyakarta: n=1004, MAPE=0.1055
# [80/20] Beras Premium - DKI Jakarta: n=1004, MAPE=0.0489
# [80/20] Beras Premium - Gorontalo: n=1004, MAPE=0.1485
# [80/20] Beras Premium - Jambi: n=1004, MAPE=0.0269
# [80/20] Beras Premium - Jawa Barat: n=1004, MAPE=0.0838
# [80/20] Beras Premium - Jawa Tengah: n=1004, MAPE=0.0764
# [80/20] Beras Premium - Jawa Timur: n=1004, MAPE=0.0551
# [80/20] Beras Premium - Kalimantan Barat: n=1004, MAPE=0.0118
# [80/20] Beras Premium - Kalimantan Selatan: n=1004, MAPE=0.0171
# [80/20] Beras Premium - Kalimantan Tengah: n=1004, MAPE=0.0130
# [80/20] Beras Premium - Kalimantan Timur: n=1004, MAPE=0.0273
# [80/20] Beras Premium - Kalimantan Utara: n=1004, MAPE=0.0074
# [80/20] Beras Premium - Kepulauan Bangka Belitung: n=1004, MAPE=0.0684
# [80/20] Beras Premium - Kepulauan Riau: n=1004, MAPE=0.0145
# [80/20] Beras Premium - Lampung: n=1004, MAPE=0.0850
# [80/20] Beras Premium - Maluku: n=1004, MAPE=0.0097
# [80/20] Beras Premium - Maluku Utara: n=1004, MAPE=0.0050
# [80/20] Beras Premium - Nusa Tenggara Barat: n=1004, MAPE=0.1265
# [80/20] Beras Premium - Nusa Tenggara Timur: n=1004, MAPE=0.0711
# [80/20] Beras Premium - Papua: n=1004, MAPE=0.0086
# [80/20] Beras Premium - Papua Barat: n=1004, MAPE=0.0110
# [80/20] Beras Premium - Riau: n=1004, MAPE=0.0180
# [80/20] Beras Premium - Sulawesi Barat: n=1004, MAPE=0.0904
# [80/20] Beras Premium - Sulawesi Selatan: n=1004, MAPE=0.0805
# [80/20] Beras Premium - Sulawesi Tengah: n=1004, MAPE=0.0658
# [80/20] Beras Premium - Sulawesi Tenggara: n=1004, MAPE=0.1279
# [80/20] Beras Premium - Sulawesi Utara: n=1004, MAPE=0.0993
# [80/20] Beras Premium - Sumatera Barat: n=1004, MAPE=0.0070
# [80/20] Beras Premium - Sumatera Selatan: n=1004, MAPE=0.0402
# [80/20] Beras Premium - Sumatera Utara: n=1004, MAPE=0.0070
# [80/20] Cabai Merah Keriting - Aceh: n=1004, MAPE=0.5700
# [80/20] Cabai Merah Keriting - Bali: n=1004, MAPE=0.8426
# [80/20] Cabai Merah Keriting - Banten: n=1004, MAPE=0.6996
# [80/20] Cabai Merah Keriting - Bengkulu: n=1004, MAPE=0.6339
# [80/20] Cabai Merah Keriting - DI Yogyakarta: n=1004, MAPE=0.8257
# [80/20] Cabai Merah Keriting - DKI Jakarta: n=1004, MAPE=0.6823
# [80/20] Cabai Merah Keriting - Gorontalo: n=1004, MAPE=0.2323
# [80/20] Cabai Merah Keriting - Jambi: n=1004, MAPE=0.9376
# [80/20] Cabai Merah Keriting - Jawa Barat: n=1004, MAPE=0.7197
# [80/20] Cabai Merah Keriting - Jawa Tengah: n=1004, MAPE=0.6954
# [80/20] Cabai Merah Keriting - Jawa Timur: n=1004, MAPE=0.6036
# [80/20] Cabai Merah Keriting - Kalimantan Barat: n=1004, MAPE=0.0862
# [80/20] Cabai Merah Keriting - Kalimantan Selatan: n=1004, MAPE=0.7041
# [80/20] Cabai Merah Keriting - Kalimantan Tengah: n=1004, MAPE=0.3078
# [80/20] Cabai Merah Keriting - Kalimantan Timur: n=1004, MAPE=0.3028
# [80/20] Cabai Merah Keriting - Kalimantan Utara: n=1004, MAPE=0.1499
# [80/20] Cabai Merah Keriting - Kepulauan Bangka Belitung: n=1004, MAPE=0.5216
# [80/20] Cabai Merah Keriting - Kepulauan Riau: n=1004, MAPE=0.3465
# [80/20] Cabai Merah Keriting - Lampung: n=1004, MAPE=0.7844
# [80/20] Cabai Merah Keriting - Maluku: n=1004, MAPE=0.1286
# [80/20] Cabai Merah Keriting - Maluku Utara: n=1004, MAPE=0.1594
# [80/20] Cabai Merah Keriting - Nusa Tenggara Barat: n=1004, MAPE=0.7602
# [80/20] Cabai Merah Keriting - Nusa Tenggara Timur: n=1004, MAPE=0.1065
# [80/20] Cabai Merah Keriting - Papua: n=1004, MAPE=0.2156
# [80/20] Cabai Merah Keriting - Papua Barat: n=1004, MAPE=0.2135
# [80/20] Cabai Merah Keriting - Riau: n=1004, MAPE=0.5574
# [80/20] Cabai Merah Keriting - Sulawesi Barat: n=1004, MAPE=0.6703
# [80/20] Cabai Merah Keriting - Sulawesi Selatan: n=1004, MAPE=0.5756
# [80/20] Cabai Merah Keriting - Sulawesi Tengah: n=1004, MAPE=0.1602
# [80/20] Cabai Merah Keriting - Sulawesi Tenggara: n=1004, MAPE=0.2039
# [80/20] Cabai Merah Keriting - Sulawesi Utara: n=1004, MAPE=0.2951
# [80/20] Cabai Merah Keriting - Sumatera Barat: n=1004, MAPE=0.7549
# [80/20] Cabai Merah Keriting - Sumatera Selatan: n=1004, MAPE=0.7131
# [80/20] Cabai Merah Keriting - Sumatera Utara: n=1004, MAPE=0.6908
# [80/20] Cabai Rawit Merah - Aceh: n=1004, MAPE=0.3595
# [80/20] Cabai Rawit Merah - Bali: n=1004, MAPE=0.6781
# [80/20] Cabai Rawit Merah - Banten: n=1004, MAPE=0.5078
# [80/20] Cabai Rawit Merah - Bengkulu: n=1004, MAPE=0.4066
# [80/20] Cabai Rawit Merah - DI Yogyakarta: n=1004, MAPE=0.6123
# [80/20] Cabai Rawit Merah - DKI Jakarta: n=1004, MAPE=0.5515
# [80/20] Cabai Rawit Merah - Gorontalo: n=1004, MAPE=0.1721
# [80/20] Cabai Rawit Merah - Jambi: n=1004, MAPE=0.5645
# [80/20] Cabai Rawit Merah - Jawa Barat: n=1004, MAPE=0.5456
# [80/20] Cabai Rawit Merah - Jawa Tengah: n=1004, MAPE=0.5584
# [80/20] Cabai Rawit Merah - Jawa Timur: n=1004, MAPE=0.5617
# [80/20] Cabai Rawit Merah - Kalimantan Barat: n=1004, MAPE=0.2023
# [80/20] Cabai Rawit Merah - Kalimantan Selatan: n=1004, MAPE=0.4286
# [80/20] Cabai Rawit Merah - Kalimantan Tengah: n=1004, MAPE=0.3348
# [80/20] Cabai Rawit Merah - Kalimantan Timur: n=1004, MAPE=0.3294
# [80/20] Cabai Rawit Merah - Kalimantan Utara: n=1004, MAPE=0.2065
# [80/20] Cabai Rawit Merah - Kepulauan Bangka Belitung: n=1004, MAPE=0.3776
# [80/20] Cabai Rawit Merah - Kepulauan Riau: n=1004, MAPE=0.2347
# [80/20] Cabai Rawit Merah - Lampung: n=1004, MAPE=0.3547
# [80/20] Cabai Rawit Merah - Maluku: n=1004, MAPE=0.2333
# [80/20] Cabai Rawit Merah - Maluku Utara: n=1004, MAPE=0.1243
# [80/20] Cabai Rawit Merah - Nusa Tenggara Barat: n=1004, MAPE=0.3762
# [80/20] Cabai Rawit Merah - Nusa Tenggara Timur: n=1004, MAPE=0.1874
# [80/20] Cabai Rawit Merah - Papua: n=1004, MAPE=0.3319
# [80/20] Cabai Rawit Merah - Papua Barat: n=1004, MAPE=0.2089
# [80/20] Cabai Rawit Merah - Riau: n=1004, MAPE=0.2908
# [80/20] Cabai Rawit Merah - Sulawesi Barat: n=1004, MAPE=0.1007
# [80/20] Cabai Rawit Merah - Sulawesi Selatan: n=1004, MAPE=0.2282
# [80/20] Cabai Rawit Merah - Sulawesi Tengah: n=1004, MAPE=0.1582
# [80/20] Cabai Rawit Merah - Sulawesi Tenggara: n=1004, MAPE=0.1234
# [80/20] Cabai Rawit Merah - Sulawesi Utara: n=1004, MAPE=0.1516
# [80/20] Cabai Rawit Merah - Sumatera Barat: n=1004, MAPE=0.3806
# [80/20] Cabai Rawit Merah - Sumatera Selatan: n=1004, MAPE=0.5422
# [80/20] Cabai Rawit Merah - Sumatera Utara: n=1004, MAPE=0.2054
# [80/20] Daging Ayam Ras - Aceh: n=1004, MAPE=0.1045
# [80/20] Daging Ayam Ras - Bali: n=1004, MAPE=0.0189
# [80/20] Daging Ayam Ras - Banten: n=1004, MAPE=0.0558
# [80/20] Daging Ayam Ras - Bengkulu: n=1004, MAPE=0.1353
# [80/20] Daging Ayam Ras - DI Yogyakarta: n=1004, MAPE=0.1088
# [80/20] Daging Ayam Ras - DKI Jakarta: n=1004, MAPE=0.0337
# [80/20] Daging Ayam Ras - Gorontalo: n=1004, MAPE=0.1046
# [80/20] Daging Ayam Ras - Jambi: n=1004, MAPE=0.1446
# [80/20] Daging Ayam Ras - Jawa Barat: n=1004, MAPE=0.0992
# [80/20] Daging Ayam Ras - Jawa Tengah: n=1004, MAPE=0.0645
# [80/20] Daging Ayam Ras - Jawa Timur: n=1004, MAPE=0.1200
# [80/20] Daging Ayam Ras - Kalimantan Barat: n=1004, MAPE=0.0604
# [80/20] Daging Ayam Ras - Kalimantan Selatan: n=1004, MAPE=0.0790
# [80/20] Daging Ayam Ras - Kalimantan Tengah: n=1004, MAPE=0.0738
# [80/20] Daging Ayam Ras - Kalimantan Timur: n=1004, MAPE=0.0559
# [80/20] Daging Ayam Ras - Kalimantan Utara: n=1004, MAPE=0.0372
# [80/20] Daging Ayam Ras - Kepulauan Bangka Belitung: n=1004, MAPE=0.0334
# [80/20] Daging Ayam Ras - Kepulauan Riau: n=1004, MAPE=0.0185
# [80/20] Daging Ayam Ras - Lampung: n=1004, MAPE=0.0377
# [80/20] Daging Ayam Ras - Maluku: n=1004, MAPE=0.0311
# [80/20] Daging Ayam Ras - Maluku Utara: n=1004, MAPE=0.0179
# [80/20] Daging Ayam Ras - Nusa Tenggara Barat: n=1004, MAPE=0.0446
# [80/20] Daging Ayam Ras - Nusa Tenggara Timur: n=1004, MAPE=0.0171
# [80/20] Daging Ayam Ras - Papua: n=1004, MAPE=0.0796
# [80/20] Daging Ayam Ras - Papua Barat: n=1004, MAPE=0.0480
# [80/20] Daging Ayam Ras - Riau: n=1004, MAPE=0.1504
# [80/20] Daging Ayam Ras - Sulawesi Barat: n=1004, MAPE=0.0457
# [80/20] Daging Ayam Ras - Sulawesi Selatan: n=1004, MAPE=0.0955
# [80/20] Daging Ayam Ras - Sulawesi Tengah: n=1004, MAPE=0.0648
# [80/20] Daging Ayam Ras - Sulawesi Tenggara: n=1004, MAPE=0.0697
# [80/20] Daging Ayam Ras - Sulawesi Utara: n=1004, MAPE=0.0707
# [80/20] Daging Ayam Ras - Sumatera Barat: n=1004, MAPE=0.0595
# [80/20] Daging Ayam Ras - Sumatera Selatan: n=1004, MAPE=0.1292
# [80/20] Daging Ayam Ras - Sumatera Utara: n=1004, MAPE=0.1581
# [80/20] Daging Sapi Murni - Aceh: n=1004, MAPE=0.0349
# [80/20] Daging Sapi Murni - Bali: n=1004, MAPE=0.0109
# [80/20] Daging Sapi Murni - Banten: n=1004, MAPE=0.0137
# [80/20] Daging Sapi Murni - Bengkulu: n=1004, MAPE=0.0227
# [80/20] Daging Sapi Murni - DI Yogyakarta: n=1004, MAPE=0.0069
# [80/20] Daging Sapi Murni - DKI Jakarta: n=1004, MAPE=0.0201
# [80/20] Daging Sapi Murni - Gorontalo: n=1004, MAPE=0.0056
# [80/20] Daging Sapi Murni - Jambi: n=1004, MAPE=0.0341
# [80/20] Daging Sapi Murni - Jawa Barat: n=1004, MAPE=0.0302
# [80/20] Daging Sapi Murni - Jawa Tengah: n=1004, MAPE=0.0098
# [80/20] Daging Sapi Murni - Jawa Timur: n=1004, MAPE=0.0107
# [80/20] Daging Sapi Murni - Kalimantan Barat: n=1004, MAPE=0.0056
# [80/20] Daging Sapi Murni - Kalimantan Selatan: n=1004, MAPE=0.0084
# [80/20] Daging Sapi Murni - Kalimantan Tengah: n=1004, MAPE=0.0086
# [80/20] Daging Sapi Murni - Kalimantan Timur: n=1004, MAPE=0.0119
# [80/20] Daging Sapi Murni - Kalimantan Utara: n=1004, MAPE=0.0370
# [80/20] Daging Sapi Murni - Kepulauan Bangka Belitung: n=1004, MAPE=0.0136
# [80/20] Daging Sapi Murni - Kepulauan Riau: n=1004, MAPE=0.0138
# [80/20] Daging Sapi Murni - Lampung: n=1004, MAPE=0.0133
# [80/20] Daging Sapi Murni - Maluku: n=1004, MAPE=0.0223
# [80/20] Daging Sapi Murni - Maluku Utara: n=1004, MAPE=0.0216
# [80/20] Daging Sapi Murni - Nusa Tenggara Barat: n=1004, MAPE=0.0061
# [80/20] Daging Sapi Murni - Nusa Tenggara Timur: n=1004, MAPE=0.0072
# [80/20] Daging Sapi Murni - Papua: n=1004, MAPE=0.0120
# [80/20] Daging Sapi Murni - Papua Barat: n=1004, MAPE=0.0386
# [80/20] Daging Sapi Murni - Riau: n=1004, MAPE=0.0179
# [80/20] Daging Sapi Murni - Sulawesi Barat: n=1004, MAPE=0.0069
# [80/20] Daging Sapi Murni - Sulawesi Selatan: n=1004, MAPE=0.0044
# [80/20] Daging Sapi Murni - Sulawesi Tengah: n=1004, MAPE=0.0125
# [80/20] Daging Sapi Murni - Sulawesi Tenggara: n=1004, MAPE=0.0071
# [80/20] Daging Sapi Murni - Sulawesi Utara: n=1004, MAPE=0.0105
# [80/20] Daging Sapi Murni - Sumatera Barat: n=1004, MAPE=0.0118
# [80/20] Daging Sapi Murni - Sumatera Selatan: n=1004, MAPE=0.0140
# [80/20] Daging Sapi Murni - Sumatera Utara: n=1004, MAPE=0.0161
# [80/20] Gula Konsumsi - Aceh: n=1004, MAPE=0.0121
# [80/20] Gula Konsumsi - Bali: n=1004, MAPE=0.0094
# [80/20] Gula Konsumsi - Banten: n=1004, MAPE=0.0450
# [80/20] Gula Konsumsi - Bengkulu: n=1004, MAPE=0.0235
# [80/20] Gula Konsumsi - DI Yogyakarta: n=1004, MAPE=0.0222
# [80/20] Gula Konsumsi - DKI Jakarta: n=1004, MAPE=0.0982
# [80/20] Gula Konsumsi - Gorontalo: n=1004, MAPE=0.0252
# [80/20] Gula Konsumsi - Jambi: n=1004, MAPE=0.0271
# [80/20] Gula Konsumsi - Jawa Barat: n=1004, MAPE=0.0256
# [80/20] Gula Konsumsi - Jawa Tengah: n=1004, MAPE=0.0136
# [80/20] Gula Konsumsi - Jawa Timur: n=1004, MAPE=0.0177
# [80/20] Gula Konsumsi - Kalimantan Barat: n=1004, MAPE=0.0122
# [80/20] Gula Konsumsi - Kalimantan Selatan: n=1004, MAPE=0.0183
# [80/20] Gula Konsumsi - Kalimantan Tengah: n=1004, MAPE=0.0152
# [80/20] Gula Konsumsi - Kalimantan Timur: n=1004, MAPE=0.0214
# [80/20] Gula Konsumsi - Kalimantan Utara: n=1004, MAPE=0.0103
# [80/20] Gula Konsumsi - Kepulauan Bangka Belitung: n=1004, MAPE=0.0098
# [80/20] Gula Konsumsi - Kepulauan Riau: n=1004, MAPE=0.0145
# [80/20] Gula Konsumsi - Lampung: n=1004, MAPE=0.0215
# [80/20] Gula Konsumsi - Maluku: n=1004, MAPE=0.0190
# [80/20] Gula Konsumsi - Maluku Utara: n=1004, MAPE=0.0163
# [80/20] Gula Konsumsi - Nusa Tenggara Barat: n=1004, MAPE=0.0133
# [80/20] Gula Konsumsi - Nusa Tenggara Timur: n=1004, MAPE=0.0237
# [80/20] Gula Konsumsi - Papua: n=1004, MAPE=0.0301
# [80/20] Gula Konsumsi - Papua Barat: n=1004, MAPE=0.0531
# [80/20] Gula Konsumsi - Riau: n=1004, MAPE=0.0158
# [80/20] Gula Konsumsi - Sulawesi Barat: n=1004, MAPE=0.0136
# [80/20] Gula Konsumsi - Sulawesi Selatan: n=1004, MAPE=0.0128
# [80/20] Gula Konsumsi - Sulawesi Tengah: n=1004, MAPE=0.0097
# [80/20] Gula Konsumsi - Sulawesi Tenggara: n=1004, MAPE=0.0243
# [80/20] Gula Konsumsi - Sulawesi Utara: n=1004, MAPE=0.0167
# [80/20] Gula Konsumsi - Sumatera Barat: n=1004, MAPE=0.0216
# [80/20] Gula Konsumsi - Sumatera Selatan: n=1004, MAPE=0.0270
# [80/20] Gula Konsumsi - Sumatera Utara: n=1004, MAPE=0.0085
# [80/20] Minyak Goreng Curah - Aceh: n=1004, MAPE=0.0239
# [80/20] Minyak Goreng Curah - Bali: n=1004, MAPE=0.0433
# [80/20] Minyak Goreng Curah - Banten: n=1004, MAPE=0.0345
# [80/20] Minyak Goreng Curah - Bengkulu: n=1004, MAPE=0.0089
# [80/20] Minyak Goreng Curah - DI Yogyakarta: n=1004, MAPE=0.0449
# [80/20] Minyak Goreng Curah - DKI Jakarta: n=1004, MAPE=0.0475
# [80/20] Minyak Goreng Curah - Gorontalo: n=1004, MAPE=0.0942
# [80/20] Minyak Goreng Curah - Jambi: n=1004, MAPE=0.0272
# [80/20] Minyak Goreng Curah - Jawa Barat: n=1004, MAPE=0.0430
# [80/20] Minyak Goreng Curah - Jawa Tengah: n=1004, MAPE=0.0374
# [80/20] Minyak Goreng Curah - Jawa Timur: n=1004, MAPE=0.0331
# [80/20] Minyak Goreng Curah - Kalimantan Barat: n=1004, MAPE=0.0214
# [80/20] Minyak Goreng Curah - Kalimantan Selatan: n=1004, MAPE=0.0395
# [80/20] Minyak Goreng Curah - Kalimantan Tengah: n=1004, MAPE=0.0122
# [80/20] Minyak Goreng Curah - Kalimantan Timur: n=1004, MAPE=0.0246
# [80/20] Minyak Goreng Curah - Kalimantan Utara: n=1004, MAPE=0.0375
# [80/20] Minyak Goreng Curah - Kepulauan Bangka Belitung: n=1004, MAPE=0.0230
# [80/20] Minyak Goreng Curah - Kepulauan Riau: n=1004, MAPE=0.0230
# [80/20] Minyak Goreng Curah - Lampung: n=1004, MAPE=0.0366
# [80/20] Minyak Goreng Curah - Maluku: n=1004, MAPE=0.0713
# [80/20] Minyak Goreng Curah - Maluku Utara: n=1004, MAPE=0.0822
# [80/20] Minyak Goreng Curah - Nusa Tenggara Barat: n=1004, MAPE=0.0147
# [80/20] Minyak Goreng Curah - Nusa Tenggara Timur: n=1004, MAPE=0.0280
# [80/20] Minyak Goreng Curah - Papua: n=1004, MAPE=0.0244
# [80/20] Minyak Goreng Curah - Papua Barat: n=1004, MAPE=0.0337
# [80/20] Minyak Goreng Curah - Riau: n=1004, MAPE=0.0162
# [80/20] Minyak Goreng Curah - Sulawesi Barat: n=1004, MAPE=0.0207
# [80/20] Minyak Goreng Curah - Sulawesi Selatan: n=1004, MAPE=0.0236
# [80/20] Minyak Goreng Curah - Sulawesi Tengah: n=1004, MAPE=0.0166
# [80/20] Minyak Goreng Curah - Sulawesi Tenggara: n=1004, MAPE=0.0192
# [80/20] Minyak Goreng Curah - Sulawesi Utara: n=1004, MAPE=0.0184
# [80/20] Minyak Goreng Curah - Sumatera Barat: n=1004, MAPE=0.0099
# [80/20] Minyak Goreng Curah - Sumatera Selatan: n=1004, MAPE=0.0124
# [80/20] Minyak Goreng Curah - Sumatera Utara: n=1004, MAPE=0.0374
# [80/20] Minyak Goreng Kemasan Sederhana - Aceh: n=1004, MAPE=0.0152
# [80/20] Minyak Goreng Kemasan Sederhana - Bali: n=1004, MAPE=0.0310
# [80/20] Minyak Goreng Kemasan Sederhana - Banten: n=1004, MAPE=0.0565
# [80/20] Minyak Goreng Kemasan Sederhana - Bengkulu: n=1004, MAPE=0.0248
# [80/20] Minyak Goreng Kemasan Sederhana - DI Yogyakarta: n=1004, MAPE=0.0148
# [80/20] Minyak Goreng Kemasan Sederhana - DKI Jakarta: n=1004, MAPE=0.0187
# [80/20] Minyak Goreng Kemasan Sederhana - Gorontalo: n=1004, MAPE=0.0216
# [80/20] Minyak Goreng Kemasan Sederhana - Jambi: n=1004, MAPE=0.0227
# [80/20] Minyak Goreng Kemasan Sederhana - Jawa Barat: n=1004, MAPE=0.0125
# [80/20] Minyak Goreng Kemasan Sederhana - Jawa Tengah: n=1004, MAPE=0.0255
# [80/20] Minyak Goreng Kemasan Sederhana - Jawa Timur: n=1004, MAPE=0.0178
# [80/20] Minyak Goreng Kemasan Sederhana - Kalimantan Barat: n=1004, MAPE=0.0105
# [80/20] Minyak Goreng Kemasan Sederhana - Kalimantan Selatan: n=1004, MAPE=0.0189
# [80/20] Minyak Goreng Kemasan Sederhana - Kalimantan Tengah: n=1004, MAPE=0.0127
# [80/20] Minyak Goreng Kemasan Sederhana - Kalimantan Timur: n=1004, MAPE=0.0178
# [80/20] Minyak Goreng Kemasan Sederhana - Kalimantan Utara: n=1004, MAPE=0.0196
# [80/20] Minyak Goreng Kemasan Sederhana - Kepulauan Bangka Belitung: n=1004, MAPE=0.0178
# [80/20] Minyak Goreng Kemasan Sederhana - Kepulauan Riau: n=1004, MAPE=0.0160
# [80/20] Minyak Goreng Kemasan Sederhana - Lampung: n=1004, MAPE=0.0187
# [80/20] Minyak Goreng Kemasan Sederhana - Maluku: n=1004, MAPE=0.0175
# [80/20] Minyak Goreng Kemasan Sederhana - Maluku Utara: n=1004, MAPE=0.0154
# [80/20] Minyak Goreng Kemasan Sederhana - Nusa Tenggara Barat: n=1004, MAPE=0.0308
# [80/20] Minyak Goreng Kemasan Sederhana - Nusa Tenggara Timur: n=1004, MAPE=0.0098
# [80/20] Minyak Goreng Kemasan Sederhana - Papua: n=1004, MAPE=0.0196
# [80/20] Minyak Goreng Kemasan Sederhana - Papua Barat: n=1004, MAPE=0.0317
# [80/20] Minyak Goreng Kemasan Sederhana - Riau: n=1004, MAPE=0.0150
# [80/20] Minyak Goreng Kemasan Sederhana - Sulawesi Barat: n=1004, MAPE=0.0156
# [80/20] Minyak Goreng Kemasan Sederhana - Sulawesi Selatan: n=1004, MAPE=0.0230
# [80/20] Minyak Goreng Kemasan Sederhana - Sulawesi Tengah: n=1004, MAPE=0.0233
# [80/20] Minyak Goreng Kemasan Sederhana - Sulawesi Tenggara: n=1004, MAPE=0.0235
# [80/20] Minyak Goreng Kemasan Sederhana - Sulawesi Utara: n=1004, MAPE=0.0086
# [80/20] Minyak Goreng Kemasan Sederhana - Sumatera Barat: n=1004, MAPE=0.0131
# [80/20] Minyak Goreng Kemasan Sederhana - Sumatera Selatan: n=1004, MAPE=0.0201
# [80/20] Minyak Goreng Kemasan Sederhana - Sumatera Utara: n=1004, MAPE=0.0238
# [80/20] Telur Ayam Ras - Aceh: n=1004, MAPE=0.0579
# [80/20] Telur Ayam Ras - Bali: n=1004, MAPE=0.0453
# [80/20] Telur Ayam Ras - Banten: n=1004, MAPE=0.1044
# [80/20] Telur Ayam Ras - Bengkulu: n=1004, MAPE=0.0247
# [80/20] Telur Ayam Ras - DI Yogyakarta: n=1004, MAPE=0.1503
# [80/20] Telur Ayam Ras - DKI Jakarta: n=1004, MAPE=0.0937
# [80/20] Telur Ayam Ras - Gorontalo: n=1004, MAPE=0.1093
# [80/20] Telur Ayam Ras - Jambi: n=1004, MAPE=0.0275
# [80/20] Telur Ayam Ras - Jawa Barat: n=1004, MAPE=0.1342
# [80/20] Telur Ayam Ras - Jawa Tengah: n=1004, MAPE=0.1178
# [80/20] Telur Ayam Ras - Jawa Timur: n=1004, MAPE=0.1430
# [80/20] Telur Ayam Ras - Kalimantan Barat: n=1004, MAPE=0.0852
# [80/20] Telur Ayam Ras - Kalimantan Selatan: n=1004, MAPE=0.0571
# [80/20] Telur Ayam Ras - Kalimantan Tengah: n=1004, MAPE=0.0357
# [80/20] Telur Ayam Ras - Kalimantan Timur: n=1004, MAPE=0.0763
# [80/20] Telur Ayam Ras - Kalimantan Utara: n=1004, MAPE=0.0604
# [80/20] Telur Ayam Ras - Kepulauan Bangka Belitung: n=1004, MAPE=0.0357
# [80/20] Telur Ayam Ras - Kepulauan Riau: n=1004, MAPE=0.0451
# [80/20] Telur Ayam Ras - Lampung: n=1004, MAPE=0.0679
# [80/20] Telur Ayam Ras - Maluku: n=1004, MAPE=0.0274
# [80/20] Telur Ayam Ras - Maluku Utara: n=1004, MAPE=0.0331
# [80/20] Telur Ayam Ras - Nusa Tenggara Barat: n=1004, MAPE=0.0634
# [80/20] Telur Ayam Ras - Nusa Tenggara Timur: n=1004, MAPE=0.0347
# [80/20] Telur Ayam Ras - Papua: n=1004, MAPE=0.0123
# [80/20] Telur Ayam Ras - Papua Barat: n=1004, MAPE=0.0119
# [80/20] Telur Ayam Ras - Riau: n=1004, MAPE=0.0200
# [80/20] Telur Ayam Ras - Sulawesi Barat: n=1004, MAPE=0.1126
# [80/20] Telur Ayam Ras - Sulawesi Selatan: n=1004, MAPE=0.1158
# [80/20] Telur Ayam Ras - Sulawesi Tengah: n=1004, MAPE=0.0653
# [80/20] Telur Ayam Ras - Sulawesi Tenggara: n=1004, MAPE=0.1250
# [80/20] Telur Ayam Ras - Sulawesi Utara: n=1004, MAPE=0.0595
# [80/20] Telur Ayam Ras - Sumatera Barat: n=1004, MAPE=0.0219
# [80/20] Telur Ayam Ras - Sumatera Selatan: n=1004, MAPE=0.0867
# [80/20] Telur Ayam Ras - Sumatera Utara: n=1004, MAPE=0.0180
# [80/20] Tepung Terigu (Curah) - Aceh: n=1004, MAPE=0.0111
# [80/20] Tepung Terigu (Curah) - Bali: n=1004, MAPE=0.1087
# [80/20] Tepung Terigu (Curah) - Banten: n=1004, MAPE=0.0092
# [80/20] Tepung Terigu (Curah) - Bengkulu: n=1004, MAPE=0.0138
# [80/20] Tepung Terigu (Curah) - DI Yogyakarta: n=1004, MAPE=0.0535
# [80/20] Tepung Terigu (Curah) - DKI Jakarta: n=1004, MAPE=0.0107
# [80/20] Tepung Terigu (Curah) - Gorontalo: n=1004, MAPE=0.0215
# [80/20] Tepung Terigu (Curah) - Jambi: n=1004, MAPE=0.0075
# [80/20] Tepung Terigu (Curah) - Jawa Barat: n=1004, MAPE=0.0127
# [80/20] Tepung Terigu (Curah) - Jawa Tengah: n=1004, MAPE=0.0318
# [80/20] Tepung Terigu (Curah) - Jawa Timur: n=1004, MAPE=0.0214
# [80/20] Tepung Terigu (Curah) - Kalimantan Barat: n=1004, MAPE=0.0103
# [80/20] Tepung Terigu (Curah) - Kalimantan Selatan: n=1004, MAPE=0.0090
# [80/20] Tepung Terigu (Curah) - Kalimantan Tengah: n=1004, MAPE=0.0323
# [80/20] Tepung Terigu (Curah) - Kalimantan Timur: n=1004, MAPE=0.0383
# [80/20] Tepung Terigu (Curah) - Kalimantan Utara: n=1004, MAPE=0.0281
# [80/20] Tepung Terigu (Curah) - Kepulauan Bangka Belitung: n=1004, MAPE=0.0279
# [80/20] Tepung Terigu (Curah) - Kepulauan Riau: n=1004, MAPE=0.0318
# [80/20] Tepung Terigu (Curah) - Lampung: n=1004, MAPE=0.0122
# [80/20] Tepung Terigu (Curah) - Maluku: n=1004, MAPE=0.0279
# [80/20] Tepung Terigu (Curah) - Maluku Utara: n=1004, MAPE=0.0248
# [80/20] Tepung Terigu (Curah) - Nusa Tenggara Barat: n=1004, MAPE=0.0099
# [80/20] Tepung Terigu (Curah) - Nusa Tenggara Timur: n=1004, MAPE=0.0383
# [80/20] Tepung Terigu (Curah) - Papua: n=1004, MAPE=0.0062
# [80/20] Tepung Terigu (Curah) - Papua Barat: n=1004, MAPE=0.0190
# [80/20] Tepung Terigu (Curah) - Riau: n=1004, MAPE=0.0420
# [80/20] Tepung Terigu (Curah) - Sulawesi Barat: n=1004, MAPE=0.0182
# [80/20] Tepung Terigu (Curah) - Sulawesi Selatan: n=1004, MAPE=0.0128
# [80/20] Tepung Terigu (Curah) - Sulawesi Tengah: n=1004, MAPE=0.0171
# [80/20] Tepung Terigu (Curah) - Sulawesi Tenggara: n=1004, MAPE=0.0335
# [80/20] Tepung Terigu (Curah) - Sulawesi Utara: n=1004, MAPE=0.0219
# [80/20] Tepung Terigu (Curah) - Sumatera Barat: n=1004, MAPE=0.0334
# [80/20] Tepung Terigu (Curah) - Sumatera Selatan: n=1004, MAPE=0.0353
# [80/20] Tepung Terigu (Curah) - Sumatera Utara: n=1004, MAPE=0.0085
# Prediksi selesai! File 'final_xgb.csv' telah dibuat 🚀
# Hasil MAPE telah disimpan ke 'mape_results_final_xgb.xlsx'.

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_percentage_error
import warnings

# Abaikan warning yang tidak perlu
warnings.filterwarnings("ignore")

# --- Asumsi: DataFrame train dan test sudah tersedia ---
# Contoh:
# train = pd.read_csv('data_train.csv')
# test = pd.read_csv('data_test.csv')

# Siapkan hasil submission (salinan dari test)
submission = test.copy()
submission['price'] = np.nan  # Inisialisasi kolom prediksi

# List untuk menyimpan detail MAPE tiap kombinasi (komoditas, provinsi)
mape_list = []

# Looping berdasarkan kombinasi: *komoditas* terlebih dahulu, kemudian *provinsi*
for (komoditas, provinsi), group in train.groupby(['komoditas', 'provinsi']):
    # Filter data train & test yang sesuai
    train_data = group.sort_values('Date')
    test_data = test[(test['komoditas'] == komoditas) & (test['provinsi'] == provinsi)].sort_values('Date')
    
    if len(train_data) < 30:
        print(f"Data terlalu sedikit untuk {komoditas} - {provinsi}, skip...")
        continue
    
    n = len(train_data)
    split_idx = int(n * 0.8)
    if split_idx < 1 or split_idx == n:
        print(f"Data untuk {komoditas} - {provinsi} tidak cukup untuk split 80/20.")
        continue

    # --- Evaluasi MAPE menggunakan 80/20 split ---
    train_eval = train_data.iloc[:split_idx]
    val_eval   = train_data.iloc[split_idx:]
    
    try:
        # Feature & Target
        X_train = np.arange(len(train_eval)).reshape(-1, 1)
        y_train = train_eval['harga'].values
        X_val = np.arange(len(train_eval), len(train_eval) + len(val_eval)).reshape(-1, 1)
        y_val = val_eval['harga'].values
        
        # Train model
        model_eval = RandomForestRegressor(n_estimators=100, random_state=42)
        model_eval.fit(X_train, y_train)
        forecast_eval = model_eval.predict(X_val)
        
        # Hitung MAPE
        mape = mean_absolute_percentage_error(y_val, forecast_eval)
        mape_list.append({'komoditas': komoditas, 'provinsi': provinsi, 'n_data': n, 'mape': mape})
        print(f"[80/20] {komoditas} - {provinsi}: n={n}, MAPE={mape:.4f}")
    except Exception as e:
        print(f"Gagal evaluasi {komoditas} - {provinsi}: {e}")
        continue

    # --- Pelatihan model final menggunakan 100% data ---
    try:
        X_full = np.arange(len(train_data)).reshape(-1, 1)
        y_full = train_data['harga'].values
        X_test = np.arange(len(train_data), len(train_data) + len(test_data)).reshape(-1, 1)
        
        model_final = RandomForestRegressor(n_estimators=100, random_state=42)
        model_final.fit(X_full, y_full)
        forecast_final = model_final.predict(X_test)
        
        # Masukkan hasil prediksi ke submission
        submission.loc[test_data.index, 'price'] = forecast_final
    except Exception as e:
        print(f"Gagal proses final {komoditas} - {provinsi}: {e}")
        continue

# Hapus kolom yang tidak diperlukan pada submission
submission = submission.drop(columns=['provinsi', 'komoditas', 'Date'])

# Simpan file submission ke CSV
submission.to_csv('final_rf.csv', index=False)
print("Prediksi selesai! File 'final_rf.csv' telah dibuat 🚀")

# --- Simpan hasil MAPE ke file Excel ---
df_mape = pd.DataFrame(mape_list)
if not df_mape.empty:
    overall_avg_mape = df_mape['mape'].mean()
else:
    overall_avg_mape = None

df_overall = pd.DataFrame({'overall_avg_mape': [overall_avg_mape], 'n_models': [len(df_mape)]})

with pd.ExcelWriter('mape_results_final_rf.xlsx') as writer:
    df_mape.to_excel(writer, sheet_name='MAPE_Detail', index=False)
    df_overall.to_excel(writer, sheet_name='MAPE_Overall', index=False)

print("Hasil MAPE telah disimpan ke 'mape_results_final_rf.xlsx'.")
# Out:
# [80/20] Bawang Merah - Aceh: n=1004, MAPE=0.2756
# [80/20] Bawang Merah - Bali: n=1004, MAPE=0.2111
# [80/20] Bawang Merah - Banten: n=1004, MAPE=0.2242
# [80/20] Bawang Merah - Bengkulu: n=1004, MAPE=0.2757
# [80/20] Bawang Merah - DI Yogyakarta: n=1004, MAPE=0.3093
# [80/20] Bawang Merah - DKI Jakarta: n=1004, MAPE=0.2137
# [80/20] Bawang Merah - Gorontalo: n=1004, MAPE=0.2088
# [80/20] Bawang Merah - Jambi: n=1004, MAPE=0.2565
# [80/20] Bawang Merah - Jawa Barat: n=1004, MAPE=0.2258
# [80/20] Bawang Merah - Jawa Tengah: n=1004, MAPE=0.2600
# [80/20] Bawang Merah - Jawa Timur: n=1004, MAPE=0.2729
# [80/20] Bawang Merah - Kalimantan Barat: n=1004, MAPE=0.1488
# [80/20] Bawang Merah - Kalimantan Selatan: n=1004, MAPE=0.2194
# [80/20] Bawang Merah - Kalimantan Tengah: n=1004, MAPE=0.1996
# [80/20] Bawang Merah - Kalimantan Timur: n=1004, MAPE=0.1614
# [80/20] Bawang Merah - Kalimantan Utara: n=1004, MAPE=0.1596
# [80/20] Bawang Merah - Kepulauan Bangka Belitung: n=1004, MAPE=0.2518
# [80/20] Bawang Merah - Kepulauan Riau: n=1004, MAPE=0.0800
# [80/20] Bawang Merah - Lampung: n=1004, MAPE=0.2934
# [80/20] Bawang Merah - Maluku: n=1004, MAPE=0.1506
# [80/20] Bawang Merah - Maluku Utara: n=1004, MAPE=0.0827
# [80/20] Bawang Merah - Nusa Tenggara Barat: n=1004, MAPE=0.3439
# [80/20] Bawang Merah - Nusa Tenggara Timur: n=1004, MAPE=0.3008
# [80/20] Bawang Merah - Papua: n=1004, MAPE=0.0711
# [80/20] Bawang Merah - Papua Barat: n=1004, MAPE=0.0616
# [80/20] Bawang Merah - Riau: n=1004, MAPE=0.2503
# [80/20] Bawang Merah - Sulawesi Barat: n=1004, MAPE=0.1940
# [80/20] Bawang Merah - Sulawesi Selatan: n=1004, MAPE=0.1950
# [80/20] Bawang Merah - Sulawesi Tengah: n=1004, MAPE=0.1850
# [80/20] Bawang Merah - Sulawesi Tenggara: n=1004, MAPE=0.2046
# [80/20] Bawang Merah - Sulawesi Utara: n=1004, MAPE=0.1748
# [80/20] Bawang Merah - Sumatera Barat: n=1004, MAPE=0.3035
# [80/20] Bawang Merah - Sumatera Selatan: n=1004, MAPE=0.2856
# [80/20] Bawang Merah - Sumatera Utara: n=1004, MAPE=0.2464
# [80/20] Bawang Putih Bonggol - Aceh: n=1004, MAPE=0.0228
# [80/20] Bawang Putih Bonggol - Bali: n=1004, MAPE=0.0330
# [80/20] Bawang Putih Bonggol - Banten: n=1004, MAPE=0.0600
# [80/20] Bawang Putih Bonggol - Bengkulu: n=1004, MAPE=0.0547
# [80/20] Bawang Putih Bonggol - DI Yogyakarta: n=1004, MAPE=0.0276
# [80/20] Bawang Putih Bonggol - DKI Jakarta: n=1004, MAPE=0.0634
# [80/20] Bawang Putih Bonggol - Gorontalo: n=1004, MAPE=0.0814
# [80/20] Bawang Putih Bonggol - Jambi: n=1004, MAPE=0.0380
# [80/20] Bawang Putih Bonggol - Jawa Barat: n=1004, MAPE=0.0396
# [80/20] Bawang Putih Bonggol - Jawa Tengah: n=1004, MAPE=0.0289
# [80/20] Bawang Putih Bonggol - Jawa Timur: n=1004, MAPE=0.0268
# [80/20] Bawang Putih Bonggol - Kalimantan Barat: n=1004, MAPE=0.0646
# [80/20] Bawang Putih Bonggol - Kalimantan Selatan: n=1004, MAPE=0.0364
# [80/20] Bawang Putih Bonggol - Kalimantan Tengah: n=1004, MAPE=0.0430
# [80/20] Bawang Putih Bonggol - Kalimantan Timur: n=1004, MAPE=0.0412
# [80/20] Bawang Putih Bonggol - Kalimantan Utara: n=1004, MAPE=0.0480
# [80/20] Bawang Putih Bonggol - Kepulauan Bangka Belitung: n=1004, MAPE=0.0579
# [80/20] Bawang Putih Bonggol - Kepulauan Riau: n=1004, MAPE=0.0615
# [80/20] Bawang Putih Bonggol - Lampung: n=1004, MAPE=0.0515
# [80/20] Bawang Putih Bonggol - Maluku: n=1004, MAPE=0.0441
# [80/20] Bawang Putih Bonggol - Maluku Utara: n=1004, MAPE=0.0371
# [80/20] Bawang Putih Bonggol - Nusa Tenggara Barat: n=1004, MAPE=0.0371
# [80/20] Bawang Putih Bonggol - Nusa Tenggara Timur: n=1004, MAPE=0.0559
# [80/20] Bawang Putih Bonggol - Papua: n=1004, MAPE=0.0352
# [80/20] Bawang Putih Bonggol - Papua Barat: n=1004, MAPE=0.0369
# [80/20] Bawang Putih Bonggol - Riau: n=1004, MAPE=0.0306
# [80/20] Bawang Putih Bonggol - Sulawesi Barat: n=1004, MAPE=0.0334
# [80/20] Bawang Putih Bonggol - Sulawesi Selatan: n=1004, MAPE=0.0211
# [80/20] Bawang Putih Bonggol - Sulawesi Tengah: n=1004, MAPE=0.0431
# [80/20] Bawang Putih Bonggol - Sulawesi Tenggara: n=1004, MAPE=0.0568
# [80/20] Bawang Putih Bonggol - Sulawesi Utara: n=1004, MAPE=0.1162
# [80/20] Bawang Putih Bonggol - Sumatera Barat: n=1004, MAPE=0.0180
# [80/20] Bawang Putih Bonggol - Sumatera Selatan: n=1004, MAPE=0.0506
# [80/20] Bawang Putih Bonggol - Sumatera Utara: n=1004, MAPE=0.0275
# [80/20] Beras Medium - Aceh: n=1004, MAPE=0.0077
# [80/20] Beras Medium - Bali: n=1004, MAPE=0.0759
# [80/20] Beras Medium - Banten: n=1004, MAPE=0.1315
# [80/20] Beras Medium - Bengkulu: n=1004, MAPE=0.0337
# [80/20] Beras Medium - DI Yogyakarta: n=1004, MAPE=0.1254
# [80/20] Beras Medium - DKI Jakarta: n=1004, MAPE=0.0583
# [80/20] Beras Medium - Gorontalo: n=1004, MAPE=0.1671
# [80/20] Beras Medium - Jambi: n=1004, MAPE=0.0340
# [80/20] Beras Medium - Jawa Barat: n=1004, MAPE=0.1279
# [80/20] Beras Medium - Jawa Tengah: n=1004, MAPE=0.1132
# [80/20] Beras Medium - Jawa Timur: n=1004, MAPE=0.0291
# [80/20] Beras Medium - Kalimantan Barat: n=1004, MAPE=0.0086
# [80/20] Beras Medium - Kalimantan Selatan: n=1004, MAPE=0.0264
# [80/20] Beras Medium - Kalimantan Tengah: n=1004, MAPE=0.0262
# [80/20] Beras Medium - Kalimantan Timur: n=1004, MAPE=0.0282
# [80/20] Beras Medium - Kalimantan Utara: n=1004, MAPE=0.0138
# [80/20] Beras Medium - Kepulauan Bangka Belitung: n=1004, MAPE=0.0456
# [80/20] Beras Medium - Kepulauan Riau: n=1004, MAPE=0.0125
# [80/20] Beras Medium - Lampung: n=1004, MAPE=0.0976
# [80/20] Beras Medium - Maluku: n=1004, MAPE=0.0092
# [80/20] Beras Medium - Maluku Utara: n=1004, MAPE=0.0282
# [80/20] Beras Medium - Nusa Tenggara Barat: n=1004, MAPE=0.1024
# [80/20] Beras Medium - Nusa Tenggara Timur: n=1004, MAPE=0.1143
# [80/20] Beras Medium - Papua: n=1004, MAPE=0.0290
# [80/20] Beras Medium - Papua Barat: n=1004, MAPE=0.0221
# [80/20] Beras Medium - Riau: n=1004, MAPE=0.0167
# [80/20] Beras Medium - Sulawesi Barat: n=1004, MAPE=0.1056
# [80/20] Beras Medium - Sulawesi Selatan: n=1004, MAPE=0.1016
# [80/20] Beras Medium - Sulawesi Tengah: n=1004, MAPE=0.0830
# [80/20] Beras Medium - Sulawesi Tenggara: n=1004, MAPE=0.0817
# [80/20] Beras Medium - Sulawesi Utara: n=1004, MAPE=0.1031
# [80/20] Beras Medium - Sumatera Barat: n=1004, MAPE=0.0187
# [80/20] Beras Medium - Sumatera Selatan: n=1004, MAPE=0.0755
# [80/20] Beras Medium - Sumatera Utara: n=1004, MAPE=0.0108
# [80/20] Beras Premium - Aceh: n=1004, MAPE=0.0061
# [80/20] Beras Premium - Bali: n=1004, MAPE=0.0650
# [80/20] Beras Premium - Banten: n=1004, MAPE=0.0867
# [80/20] Beras Premium - Bengkulu: n=1004, MAPE=0.0413
# [80/20] Beras Premium - DI Yogyakarta: n=1004, MAPE=0.1047
# [80/20] Beras Premium - DKI Jakarta: n=1004, MAPE=0.0656
# [80/20] Beras Premium - Gorontalo: n=1004, MAPE=0.1487
# [80/20] Beras Premium - Jambi: n=1004, MAPE=0.0231
# [80/20] Beras Premium - Jawa Barat: n=1004, MAPE=0.0819
# [80/20] Beras Premium - Jawa Tengah: n=1004, MAPE=0.0751
# [80/20] Beras Premium - Jawa Timur: n=1004, MAPE=0.0517
# [80/20] Beras Premium - Kalimantan Barat: n=1004, MAPE=0.0104
# [80/20] Beras Premium - Kalimantan Selatan: n=1004, MAPE=0.0188
# [80/20] Beras Premium - Kalimantan Tengah: n=1004, MAPE=0.0130
# [80/20] Beras Premium - Kalimantan Timur: n=1004, MAPE=0.0296
# [80/20] Beras Premium - Kalimantan Utara: n=1004, MAPE=0.0075
# [80/20] Beras Premium - Kepulauan Bangka Belitung: n=1004, MAPE=0.0687
# [80/20] Beras Premium - Kepulauan Riau: n=1004, MAPE=0.0187
# [80/20] Beras Premium - Lampung: n=1004, MAPE=0.0795
# [80/20] Beras Premium - Maluku: n=1004, MAPE=0.0097
# [80/20] Beras Premium - Maluku Utara: n=1004, MAPE=0.0052
# [80/20] Beras Premium - Nusa Tenggara Barat: n=1004, MAPE=0.1218
# [80/20] Beras Premium - Nusa Tenggara Timur: n=1004, MAPE=0.0748
# [80/20] Beras Premium - Papua: n=1004, MAPE=0.0078
# [80/20] Beras Premium - Papua Barat: n=1004, MAPE=0.0145
# [80/20] Beras Premium - Riau: n=1004, MAPE=0.0178
# [80/20] Beras Premium - Sulawesi Barat: n=1004, MAPE=0.0801
# [80/20] Beras Premium - Sulawesi Selatan: n=1004, MAPE=0.0802
# [80/20] Beras Premium - Sulawesi Tengah: n=1004, MAPE=0.0674
# [80/20] Beras Premium - Sulawesi Tenggara: n=1004, MAPE=0.1378
# [80/20] Beras Premium - Sulawesi Utara: n=1004, MAPE=0.1038
# [80/20] Beras Premium - Sumatera Barat: n=1004, MAPE=0.0070
# [80/20] Beras Premium - Sumatera Selatan: n=1004, MAPE=0.0407
# [80/20] Beras Premium - Sumatera Utara: n=1004, MAPE=0.0070
# [80/20] Cabai Merah Keriting - Aceh: n=1004, MAPE=0.5800
# [80/20] Cabai Merah Keriting - Bali: n=1004, MAPE=0.8747
# [80/20] Cabai Merah Keriting - Banten: n=1004, MAPE=0.8222
# [80/20] Cabai Merah Keriting - Bengkulu: n=1004, MAPE=0.5977
# [80/20] Cabai Merah Keriting - DI Yogyakarta: n=1004, MAPE=0.7331
# [80/20] Cabai Merah Keriting - DKI Jakarta: n=1004, MAPE=0.7584
# [80/20] Cabai Merah Keriting - Gorontalo: n=1004, MAPE=0.2363
# [80/20] Cabai Merah Keriting - Jambi: n=1004, MAPE=1.0651
# [80/20] Cabai Merah Keriting - Jawa Barat: n=1004, MAPE=0.7591
# [80/20] Cabai Merah Keriting - Jawa Tengah: n=1004, MAPE=0.7138
# [80/20] Cabai Merah Keriting - Jawa Timur: n=1004, MAPE=0.5741
# [80/20] Cabai Merah Keriting - Kalimantan Barat: n=1004, MAPE=0.1100
# [80/20] Cabai Merah Keriting - Kalimantan Selatan: n=1004, MAPE=0.7162
# [80/20] Cabai Merah Keriting - Kalimantan Tengah: n=1004, MAPE=0.3073
# [80/20] Cabai Merah Keriting - Kalimantan Timur: n=1004, MAPE=0.3377
# [80/20] Cabai Merah Keriting - Kalimantan Utara: n=1004, MAPE=0.1556
# [80/20] Cabai Merah Keriting - Kepulauan Bangka Belitung: n=1004, MAPE=0.5400
# [80/20] Cabai Merah Keriting - Kepulauan Riau: n=1004, MAPE=0.3710
# [80/20] Cabai Merah Keriting - Lampung: n=1004, MAPE=0.7955
# [80/20] Cabai Merah Keriting - Maluku: n=1004, MAPE=0.1294
# [80/20] Cabai Merah Keriting - Maluku Utara: n=1004, MAPE=0.1695
# [80/20] Cabai Merah Keriting - Nusa Tenggara Barat: n=1004, MAPE=0.7652
# [80/20] Cabai Merah Keriting - Nusa Tenggara Timur: n=1004, MAPE=0.1206
# [80/20] Cabai Merah Keriting - Papua: n=1004, MAPE=0.2018
# [80/20] Cabai Merah Keriting - Papua Barat: n=1004, MAPE=0.1878
# [80/20] Cabai Merah Keriting - Riau: n=1004, MAPE=0.6565
# [80/20] Cabai Merah Keriting - Sulawesi Barat: n=1004, MAPE=0.6546
# [80/20] Cabai Merah Keriting - Sulawesi Selatan: n=1004, MAPE=0.5915
# [80/20] Cabai Merah Keriting - Sulawesi Tengah: n=1004, MAPE=0.1613
# [80/20] Cabai Merah Keriting - Sulawesi Tenggara: n=1004, MAPE=0.1999
# [80/20] Cabai Merah Keriting - Sulawesi Utara: n=1004, MAPE=0.3097
# [80/20] Cabai Merah Keriting - Sumatera Barat: n=1004, MAPE=0.8053
# [80/20] Cabai Merah Keriting - Sumatera Selatan: n=1004, MAPE=0.7036
# [80/20] Cabai Merah Keriting - Sumatera Utara: n=1004, MAPE=0.8343
# [80/20] Cabai Rawit Merah - Aceh: n=1004, MAPE=0.3515
# [80/20] Cabai Rawit Merah - Bali: n=1004, MAPE=0.7420
# [80/20] Cabai Rawit Merah - Banten: n=1004, MAPE=0.5468
# [80/20] Cabai Rawit Merah - Bengkulu: n=1004, MAPE=0.3730
# [80/20] Cabai Rawit Merah - DI Yogyakarta: n=1004, MAPE=0.5162
# [80/20] Cabai Rawit Merah - DKI Jakarta: n=1004, MAPE=0.4744
# [80/20] Cabai Rawit Merah - Gorontalo: n=1004, MAPE=0.2271
# [80/20] Cabai Rawit Merah - Jambi: n=1004, MAPE=0.5340
# [80/20] Cabai Rawit Merah - Jawa Barat: n=1004, MAPE=0.5520
# [80/20] Cabai Rawit Merah - Jawa Tengah: n=1004, MAPE=0.5799
# [80/20] Cabai Rawit Merah - Jawa Timur: n=1004, MAPE=0.5412
# [80/20] Cabai Rawit Merah - Kalimantan Barat: n=1004, MAPE=0.1520
# [80/20] Cabai Rawit Merah - Kalimantan Selatan: n=1004, MAPE=0.4668
# [80/20] Cabai Rawit Merah - Kalimantan Tengah: n=1004, MAPE=0.3392
# [80/20] Cabai Rawit Merah - Kalimantan Timur: n=1004, MAPE=0.3881
# [80/20] Cabai Rawit Merah - Kalimantan Utara: n=1004, MAPE=0.1868
# [80/20] Cabai Rawit Merah - Kepulauan Bangka Belitung: n=1004, MAPE=0.4056
# [80/20] Cabai Rawit Merah - Kepulauan Riau: n=1004, MAPE=0.2858
# [80/20] Cabai Rawit Merah - Lampung: n=1004, MAPE=0.3465
# [80/20] Cabai Rawit Merah - Maluku: n=1004, MAPE=0.2631
# [80/20] Cabai Rawit Merah - Maluku Utara: n=1004, MAPE=0.1134
# [80/20] Cabai Rawit Merah - Nusa Tenggara Barat: n=1004, MAPE=0.4235
# [80/20] Cabai Rawit Merah - Nusa Tenggara Timur: n=1004, MAPE=0.2110
# [80/20] Cabai Rawit Merah - Papua: n=1004, MAPE=0.3299
# [80/20] Cabai Rawit Merah - Papua Barat: n=1004, MAPE=0.1886
# [80/20] Cabai Rawit Merah - Riau: n=1004, MAPE=0.3184
# [80/20] Cabai Rawit Merah - Sulawesi Barat: n=1004, MAPE=0.1011
# [80/20] Cabai Rawit Merah - Sulawesi Selatan: n=1004, MAPE=0.2373
# [80/20] Cabai Rawit Merah - Sulawesi Tengah: n=1004, MAPE=0.1587
# [80/20] Cabai Rawit Merah - Sulawesi Tenggara: n=1004, MAPE=0.1226
# [80/20] Cabai Rawit Merah - Sulawesi Utara: n=1004, MAPE=0.1563
# [80/20] Cabai Rawit Merah - Sumatera Barat: n=1004, MAPE=0.4686
# [80/20] Cabai Rawit Merah - Sumatera Selatan: n=1004, MAPE=0.5277
# [80/20] Cabai Rawit Merah - Sumatera Utara: n=1004, MAPE=0.3561
# [80/20] Daging Ayam Ras - Aceh: n=1004, MAPE=0.0805
# [80/20] Daging Ayam Ras - Bali: n=1004, MAPE=0.0186
# [80/20] Daging Ayam Ras - Banten: n=1004, MAPE=0.0617
# [80/20] Daging Ayam Ras - Bengkulu: n=1004, MAPE=0.1313
# [80/20] Daging Ayam Ras - DI Yogyakarta: n=1004, MAPE=0.1021
# [80/20] Daging Ayam Ras - DKI Jakarta: n=1004, MAPE=0.0362
# [80/20] Daging Ayam Ras - Gorontalo: n=1004, MAPE=0.1068
# [80/20] Daging Ayam Ras - Jambi: n=1004, MAPE=0.1505
# [80/20] Daging Ayam Ras - Jawa Barat: n=1004, MAPE=0.0959
# [80/20] Daging Ayam Ras - Jawa Tengah: n=1004, MAPE=0.0659
# [80/20] Daging Ayam Ras - Jawa Timur: n=1004, MAPE=0.1188
# [80/20] Daging Ayam Ras - Kalimantan Barat: n=1004, MAPE=0.0596
# [80/20] Daging Ayam Ras - Kalimantan Selatan: n=1004, MAPE=0.0792
# [80/20] Daging Ayam Ras - Kalimantan Tengah: n=1004, MAPE=0.0739
# [80/20] Daging Ayam Ras - Kalimantan Timur: n=1004, MAPE=0.0600
# [80/20] Daging Ayam Ras - Kalimantan Utara: n=1004, MAPE=0.0393
# [80/20] Daging Ayam Ras - Kepulauan Bangka Belitung: n=1004, MAPE=0.0333
# [80/20] Daging Ayam Ras - Kepulauan Riau: n=1004, MAPE=0.0248
# [80/20] Daging Ayam Ras - Lampung: n=1004, MAPE=0.0452
# [80/20] Daging Ayam Ras - Maluku: n=1004, MAPE=0.0238
# [80/20] Daging Ayam Ras - Maluku Utara: n=1004, MAPE=0.0189
# [80/20] Daging Ayam Ras - Nusa Tenggara Barat: n=1004, MAPE=0.0483
# [80/20] Daging Ayam Ras - Nusa Tenggara Timur: n=1004, MAPE=0.0171
# [80/20] Daging Ayam Ras - Papua: n=1004, MAPE=0.0776
# [80/20] Daging Ayam Ras - Papua Barat: n=1004, MAPE=0.0343
# [80/20] Daging Ayam Ras - Riau: n=1004, MAPE=0.1570
# [80/20] Daging Ayam Ras - Sulawesi Barat: n=1004, MAPE=0.0413
# [80/20] Daging Ayam Ras - Sulawesi Selatan: n=1004, MAPE=0.1030
# [80/20] Daging Ayam Ras - Sulawesi Tengah: n=1004, MAPE=0.0657
# [80/20] Daging Ayam Ras - Sulawesi Tenggara: n=1004, MAPE=0.0739
# [80/20] Daging Ayam Ras - Sulawesi Utara: n=1004, MAPE=0.0702
# [80/20] Daging Ayam Ras - Sumatera Barat: n=1004, MAPE=0.0654
# [80/20] Daging Ayam Ras - Sumatera Selatan: n=1004, MAPE=0.1278
# [80/20] Daging Ayam Ras - Sumatera Utara: n=1004, MAPE=0.1555
# [80/20] Daging Sapi Murni - Aceh: n=1004, MAPE=0.0185
# [80/20] Daging Sapi Murni - Bali: n=1004, MAPE=0.0112
# [80/20] Daging Sapi Murni - Banten: n=1004, MAPE=0.0138
# [80/20] Daging Sapi Murni - Bengkulu: n=1004, MAPE=0.0189
# [80/20] Daging Sapi Murni - DI Yogyakarta: n=1004, MAPE=0.0074
# [80/20] Daging Sapi Murni - DKI Jakarta: n=1004, MAPE=0.0182
# [80/20] Daging Sapi Murni - Gorontalo: n=1004, MAPE=0.0057
# [80/20] Daging Sapi Murni - Jambi: n=1004, MAPE=0.0332
# [80/20] Daging Sapi Murni - Jawa Barat: n=1004, MAPE=0.0308
# [80/20] Daging Sapi Murni - Jawa Tengah: n=1004, MAPE=0.0101
# [80/20] Daging Sapi Murni - Jawa Timur: n=1004, MAPE=0.0101
# [80/20] Daging Sapi Murni - Kalimantan Barat: n=1004, MAPE=0.0063
# [80/20] Daging Sapi Murni - Kalimantan Selatan: n=1004, MAPE=0.0080
# [80/20] Daging Sapi Murni - Kalimantan Tengah: n=1004, MAPE=0.0087
# [80/20] Daging Sapi Murni - Kalimantan Timur: n=1004, MAPE=0.0104
# [80/20] Daging Sapi Murni - Kalimantan Utara: n=1004, MAPE=0.0375
# [80/20] Daging Sapi Murni - Kepulauan Bangka Belitung: n=1004, MAPE=0.0100
# [80/20] Daging Sapi Murni - Kepulauan Riau: n=1004, MAPE=0.0142
# [80/20] Daging Sapi Murni - Lampung: n=1004, MAPE=0.0130
# [80/20] Daging Sapi Murni - Maluku: n=1004, MAPE=0.0174
# [80/20] Daging Sapi Murni - Maluku Utara: n=1004, MAPE=0.0274
# [80/20] Daging Sapi Murni - Nusa Tenggara Barat: n=1004, MAPE=0.0090
# [80/20] Daging Sapi Murni - Nusa Tenggara Timur: n=1004, MAPE=0.0079
# [80/20] Daging Sapi Murni - Papua: n=1004, MAPE=0.0120
# [80/20] Daging Sapi Murni - Papua Barat: n=1004, MAPE=0.0293
# [80/20] Daging Sapi Murni - Riau: n=1004, MAPE=0.0185
# [80/20] Daging Sapi Murni - Sulawesi Barat: n=1004, MAPE=0.0063
# [80/20] Daging Sapi Murni - Sulawesi Selatan: n=1004, MAPE=0.0043
# [80/20] Daging Sapi Murni - Sulawesi Tengah: n=1004, MAPE=0.0135
# [80/20] Daging Sapi Murni - Sulawesi Tenggara: n=1004, MAPE=0.0065
# [80/20] Daging Sapi Murni - Sulawesi Utara: n=1004, MAPE=0.0115
# [80/20] Daging Sapi Murni - Sumatera Barat: n=1004, MAPE=0.0160
# [80/20] Daging Sapi Murni - Sumatera Selatan: n=1004, MAPE=0.0122
# [80/20] Daging Sapi Murni - Sumatera Utara: n=1004, MAPE=0.0137
# [80/20] Gula Konsumsi - Aceh: n=1004, MAPE=0.0122
# [80/20] Gula Konsumsi - Bali: n=1004, MAPE=0.0090
# [80/20] Gula Konsumsi - Banten: n=1004, MAPE=0.0377
# [80/20] Gula Konsumsi - Bengkulu: n=1004, MAPE=0.0225
# [80/20] Gula Konsumsi - DI Yogyakarta: n=1004, MAPE=0.0224
# [80/20] Gula Konsumsi - DKI Jakarta: n=1004, MAPE=0.0985
# [80/20] Gula Konsumsi - Gorontalo: n=1004, MAPE=0.0263
# [80/20] Gula Konsumsi - Jambi: n=1004, MAPE=0.0229
# [80/20] Gula Konsumsi - Jawa Barat: n=1004, MAPE=0.0267
# [80/20] Gula Konsumsi - Jawa Tengah: n=1004, MAPE=0.0138
# [80/20] Gula Konsumsi - Jawa Timur: n=1004, MAPE=0.0177
# [80/20] Gula Konsumsi - Kalimantan Barat: n=1004, MAPE=0.0124
# [80/20] Gula Konsumsi - Kalimantan Selatan: n=1004, MAPE=0.0187
# [80/20] Gula Konsumsi - Kalimantan Tengah: n=1004, MAPE=0.0150
# [80/20] Gula Konsumsi - Kalimantan Timur: n=1004, MAPE=0.0210
# [80/20] Gula Konsumsi - Kalimantan Utara: n=1004, MAPE=0.0089
# [80/20] Gula Konsumsi - Kepulauan Bangka Belitung: n=1004, MAPE=0.0099
# [80/20] Gula Konsumsi - Kepulauan Riau: n=1004, MAPE=0.0144
# [80/20] Gula Konsumsi - Lampung: n=1004, MAPE=0.0222
# [80/20] Gula Konsumsi - Maluku: n=1004, MAPE=0.0153
# [80/20] Gula Konsumsi - Maluku Utara: n=1004, MAPE=0.0166
# [80/20] Gula Konsumsi - Nusa Tenggara Barat: n=1004, MAPE=0.0134
# [80/20] Gula Konsumsi - Nusa Tenggara Timur: n=1004, MAPE=0.0207
# [80/20] Gula Konsumsi - Papua: n=1004, MAPE=0.0331
# [80/20] Gula Konsumsi - Papua Barat: n=1004, MAPE=0.0466
# [80/20] Gula Konsumsi - Riau: n=1004, MAPE=0.0143
# [80/20] Gula Konsumsi - Sulawesi Barat: n=1004, MAPE=0.0123
# [80/20] Gula Konsumsi - Sulawesi Selatan: n=1004, MAPE=0.0116
# [80/20] Gula Konsumsi - Sulawesi Tengah: n=1004, MAPE=0.0092
# [80/20] Gula Konsumsi - Sulawesi Tenggara: n=1004, MAPE=0.0232
# [80/20] Gula Konsumsi - Sulawesi Utara: n=1004, MAPE=0.0165
# [80/20] Gula Konsumsi - Sumatera Barat: n=1004, MAPE=0.0178
# [80/20] Gula Konsumsi - Sumatera Selatan: n=1004, MAPE=0.0259
# [80/20] Gula Konsumsi - Sumatera Utara: n=1004, MAPE=0.0089
# [80/20] Minyak Goreng Curah - Aceh: n=1004, MAPE=0.0184
# [80/20] Minyak Goreng Curah - Bali: n=1004, MAPE=0.0430
# [80/20] Minyak Goreng Curah - Banten: n=1004, MAPE=0.0414
# [80/20] Minyak Goreng Curah - Bengkulu: n=1004, MAPE=0.0088
# [80/20] Minyak Goreng Curah - DI Yogyakarta: n=1004, MAPE=0.0375
# [80/20] Minyak Goreng Curah - DKI Jakarta: n=1004, MAPE=0.0487
# [80/20] Minyak Goreng Curah - Gorontalo: n=1004, MAPE=0.0897
# [80/20] Minyak Goreng Curah - Jambi: n=1004, MAPE=0.0249
# [80/20] Minyak Goreng Curah - Jawa Barat: n=1004, MAPE=0.0481
# [80/20] Minyak Goreng Curah - Jawa Tengah: n=1004, MAPE=0.0368
# [80/20] Minyak Goreng Curah - Jawa Timur: n=1004, MAPE=0.0355
# [80/20] Minyak Goreng Curah - Kalimantan Barat: n=1004, MAPE=0.0204
# [80/20] Minyak Goreng Curah - Kalimantan Selatan: n=1004, MAPE=0.0399
# [80/20] Minyak Goreng Curah - Kalimantan Tengah: n=1004, MAPE=0.0113
# [80/20] Minyak Goreng Curah - Kalimantan Timur: n=1004, MAPE=0.0251
# [80/20] Minyak Goreng Curah - Kalimantan Utara: n=1004, MAPE=0.0361
# [80/20] Minyak Goreng Curah - Kepulauan Bangka Belitung: n=1004, MAPE=0.0214
# [80/20] Minyak Goreng Curah - Kepulauan Riau: n=1004, MAPE=0.0235
# [80/20] Minyak Goreng Curah - Lampung: n=1004, MAPE=0.0365
# [80/20] Minyak Goreng Curah - Maluku: n=1004, MAPE=0.0681
# [80/20] Minyak Goreng Curah - Maluku Utara: n=1004, MAPE=0.0798
# [80/20] Minyak Goreng Curah - Nusa Tenggara Barat: n=1004, MAPE=0.0131
# [80/20] Minyak Goreng Curah - Nusa Tenggara Timur: n=1004, MAPE=0.0275
# [80/20] Minyak Goreng Curah - Papua: n=1004, MAPE=0.0198
# [80/20] Minyak Goreng Curah - Papua Barat: n=1004, MAPE=0.0203
# [80/20] Minyak Goreng Curah - Riau: n=1004, MAPE=0.0145
# [80/20] Minyak Goreng Curah - Sulawesi Barat: n=1004, MAPE=0.0179
# [80/20] Minyak Goreng Curah - Sulawesi Selatan: n=1004, MAPE=0.0231
# [80/20] Minyak Goreng Curah - Sulawesi Tengah: n=1004, MAPE=0.0132
# [80/20] Minyak Goreng Curah - Sulawesi Tenggara: n=1004, MAPE=0.0174
# [80/20] Minyak Goreng Curah - Sulawesi Utara: n=1004, MAPE=0.0205
# [80/20] Minyak Goreng Curah - Sumatera Barat: n=1004, MAPE=0.0055
# [80/20] Minyak Goreng Curah - Sumatera Selatan: n=1004, MAPE=0.0103
# [80/20] Minyak Goreng Curah - Sumatera Utara: n=1004, MAPE=0.0342
# [80/20] Minyak Goreng Kemasan Sederhana - Aceh: n=1004, MAPE=0.0147
# [80/20] Minyak Goreng Kemasan Sederhana - Bali: n=1004, MAPE=0.0327
# [80/20] Minyak Goreng Kemasan Sederhana - Banten: n=1004, MAPE=0.0544
# [80/20] Minyak Goreng Kemasan Sederhana - Bengkulu: n=1004, MAPE=0.0243
# [80/20] Minyak Goreng Kemasan Sederhana - DI Yogyakarta: n=1004, MAPE=0.0140
# [80/20] Minyak Goreng Kemasan Sederhana - DKI Jakarta: n=1004, MAPE=0.0194
# [80/20] Minyak Goreng Kemasan Sederhana - Gorontalo: n=1004, MAPE=0.0200
# [80/20] Minyak Goreng Kemasan Sederhana - Jambi: n=1004, MAPE=0.0225
# [80/20] Minyak Goreng Kemasan Sederhana - Jawa Barat: n=1004, MAPE=0.0106
# [80/20] Minyak Goreng Kemasan Sederhana - Jawa Tengah: n=1004, MAPE=0.0214
# [80/20] Minyak Goreng Kemasan Sederhana - Jawa Timur: n=1004, MAPE=0.0202
# [80/20] Minyak Goreng Kemasan Sederhana - Kalimantan Barat: n=1004, MAPE=0.0105
# [80/20] Minyak Goreng Kemasan Sederhana - Kalimantan Selatan: n=1004, MAPE=0.0183
# [80/20] Minyak Goreng Kemasan Sederhana - Kalimantan Tengah: n=1004, MAPE=0.0118
# [80/20] Minyak Goreng Kemasan Sederhana - Kalimantan Timur: n=1004, MAPE=0.0205
# [80/20] Minyak Goreng Kemasan Sederhana - Kalimantan Utara: n=1004, MAPE=0.0195
# [80/20] Minyak Goreng Kemasan Sederhana - Kepulauan Bangka Belitung: n=1004, MAPE=0.0185
# [80/20] Minyak Goreng Kemasan Sederhana - Kepulauan Riau: n=1004, MAPE=0.0216
# [80/20] Minyak Goreng Kemasan Sederhana - Lampung: n=1004, MAPE=0.0166
# [80/20] Minyak Goreng Kemasan Sederhana - Maluku: n=1004, MAPE=0.0186
# [80/20] Minyak Goreng Kemasan Sederhana - Maluku Utara: n=1004, MAPE=0.0125
# [80/20] Minyak Goreng Kemasan Sederhana - Nusa Tenggara Barat: n=1004, MAPE=0.0327
# [80/20] Minyak Goreng Kemasan Sederhana - Nusa Tenggara Timur: n=1004, MAPE=0.0109
# [80/20] Minyak Goreng Kemasan Sederhana - Papua: n=1004, MAPE=0.0180
# [80/20] Minyak Goreng Kemasan Sederhana - Papua Barat: n=1004, MAPE=0.0303
# [80/20] Minyak Goreng Kemasan Sederhana - Riau: n=1004, MAPE=0.0142
# [80/20] Minyak Goreng Kemasan Sederhana - Sulawesi Barat: n=1004, MAPE=0.0141
# [80/20] Minyak Goreng Kemasan Sederhana - Sulawesi Selatan: n=1004, MAPE=0.0245
# [80/20] Minyak Goreng Kemasan Sederhana - Sulawesi Tengah: n=1004, MAPE=0.0234
# [80/20] Minyak Goreng Kemasan Sederhana - Sulawesi Tenggara: n=1004, MAPE=0.0168
# [80/20] Minyak Goreng Kemasan Sederhana - Sulawesi Utara: n=1004, MAPE=0.0095
# [80/20] Minyak Goreng Kemasan Sederhana - Sumatera Barat: n=1004, MAPE=0.0137
# [80/20] Minyak Goreng Kemasan Sederhana - Sumatera Selatan: n=1004, MAPE=0.0209
# [80/20] Minyak Goreng Kemasan Sederhana - Sumatera Utara: n=1004, MAPE=0.0291
# [80/20] Telur Ayam Ras - Aceh: n=1004, MAPE=0.0605
# [80/20] Telur Ayam Ras - Bali: n=1004, MAPE=0.0455
# [80/20] Telur Ayam Ras - Banten: n=1004, MAPE=0.1016
# [80/20] Telur Ayam Ras - Bengkulu: n=1004, MAPE=0.0251
# [80/20] Telur Ayam Ras - DI Yogyakarta: n=1004, MAPE=0.1494
# [80/20] Telur Ayam Ras - DKI Jakarta: n=1004, MAPE=0.0973
# [80/20] Telur Ayam Ras - Gorontalo: n=1004, MAPE=0.1205
# [80/20] Telur Ayam Ras - Jambi: n=1004, MAPE=0.0291
# [80/20] Telur Ayam Ras - Jawa Barat: n=1004, MAPE=0.1402
# [80/20] Telur Ayam Ras - Jawa Tengah: n=1004, MAPE=0.1232
# [80/20] Telur Ayam Ras - Jawa Timur: n=1004, MAPE=0.1484
# [80/20] Telur Ayam Ras - Kalimantan Barat: n=1004, MAPE=0.0900
# [80/20] Telur Ayam Ras - Kalimantan Selatan: n=1004, MAPE=0.0695
# [80/20] Telur Ayam Ras - Kalimantan Tengah: n=1004, MAPE=0.0359
# [80/20] Telur Ayam Ras - Kalimantan Timur: n=1004, MAPE=0.0915
# [80/20] Telur Ayam Ras - Kalimantan Utara: n=1004, MAPE=0.0649
# [80/20] Telur Ayam Ras - Kepulauan Bangka Belitung: n=1004, MAPE=0.0337
# [80/20] Telur Ayam Ras - Kepulauan Riau: n=1004, MAPE=0.0453
# [80/20] Telur Ayam Ras - Lampung: n=1004, MAPE=0.0705
# [80/20] Telur Ayam Ras - Maluku: n=1004, MAPE=0.0274
# [80/20] Telur Ayam Ras - Maluku Utara: n=1004, MAPE=0.0349
# [80/20] Telur Ayam Ras - Nusa Tenggara Barat: n=1004, MAPE=0.0697
# [80/20] Telur Ayam Ras - Nusa Tenggara Timur: n=1004, MAPE=0.0471
# [80/20] Telur Ayam Ras - Papua: n=1004, MAPE=0.0160
# [80/20] Telur Ayam Ras - Papua Barat: n=1004, MAPE=0.0111
# [80/20] Telur Ayam Ras - Riau: n=1004, MAPE=0.0203
# [80/20] Telur Ayam Ras - Sulawesi Barat: n=1004, MAPE=0.1109
# [80/20] Telur Ayam Ras - Sulawesi Selatan: n=1004, MAPE=0.1201
# [80/20] Telur Ayam Ras - Sulawesi Tengah: n=1004, MAPE=0.0717
# [80/20] Telur Ayam Ras - Sulawesi Tenggara: n=1004, MAPE=0.1299
# [80/20] Telur Ayam Ras - Sulawesi Utara: n=1004, MAPE=0.0646
# [80/20] Telur Ayam Ras - Sumatera Barat: n=1004, MAPE=0.0274
# [80/20] Telur Ayam Ras - Sumatera Selatan: n=1004, MAPE=0.0915
# [80/20] Telur Ayam Ras - Sumatera Utara: n=1004, MAPE=0.0224
# [80/20] Tepung Terigu (Curah) - Aceh: n=1004, MAPE=0.0109
# [80/20] Tepung Terigu (Curah) - Bali: n=1004, MAPE=0.1020
# [80/20] Tepung Terigu (Curah) - Banten: n=1004, MAPE=0.0099
# [80/20] Tepung Terigu (Curah) - Bengkulu: n=1004, MAPE=0.0134
# [80/20] Tepung Terigu (Curah) - DI Yogyakarta: n=1004, MAPE=0.0587
# [80/20] Tepung Terigu (Curah) - DKI Jakarta: n=1004, MAPE=0.0108
# [80/20] Tepung Terigu (Curah) - Gorontalo: n=1004, MAPE=0.0239
# [80/20] Tepung Terigu (Curah) - Jambi: n=1004, MAPE=0.0097
# [80/20] Tepung Terigu (Curah) - Jawa Barat: n=1004, MAPE=0.0140
# [80/20] Tepung Terigu (Curah) - Jawa Tengah: n=1004, MAPE=0.0321
# [80/20] Tepung Terigu (Curah) - Jawa Timur: n=1004, MAPE=0.0194
# [80/20] Tepung Terigu (Curah) - Kalimantan Barat: n=1004, MAPE=0.0114
# [80/20] Tepung Terigu (Curah) - Kalimantan Selatan: n=1004, MAPE=0.0091
# [80/20] Tepung Terigu (Curah) - Kalimantan Tengah: n=1004, MAPE=0.0328
# [80/20] Tepung Terigu (Curah) - Kalimantan Timur: n=1004, MAPE=0.0360
# [80/20] Tepung Terigu (Curah) - Kalimantan Utara: n=1004, MAPE=0.0279
# [80/20] Tepung Terigu (Curah) - Kepulauan Bangka Belitung: n=1004, MAPE=0.0266
# [80/20] Tepung Terigu (Curah) - Kepulauan Riau: n=1004, MAPE=0.0287
# [80/20] Tepung Terigu (Curah) - Lampung: n=1004, MAPE=0.0146
# [80/20] Tepung Terigu (Curah) - Maluku: n=1004, MAPE=0.0282
# [80/20] Tepung Terigu (Curah) - Maluku Utara: n=1004, MAPE=0.0308
# [80/20] Tepung Terigu (Curah) - Nusa Tenggara Barat: n=1004, MAPE=0.0101
# [80/20] Tepung Terigu (Curah) - Nusa Tenggara Timur: n=1004, MAPE=0.0344
# [80/20] Tepung Terigu (Curah) - Papua: n=1004, MAPE=0.0063
# [80/20] Tepung Terigu (Curah) - Papua Barat: n=1004, MAPE=0.0188
# [80/20] Tepung Terigu (Curah) - Riau: n=1004, MAPE=0.0404
# [80/20] Tepung Terigu (Curah) - Sulawesi Barat: n=1004, MAPE=0.0197
# [80/20] Tepung Terigu (Curah) - Sulawesi Selatan: n=1004, MAPE=0.0087
# [80/20] Tepung Terigu (Curah) - Sulawesi Tengah: n=1004, MAPE=0.0284
# [80/20] Tepung Terigu (Curah) - Sulawesi Tenggara: n=1004, MAPE=0.0369
# [80/20] Tepung Terigu (Curah) - Sulawesi Utara: n=1004, MAPE=0.0220
# [80/20] Tepung Terigu (Curah) - Sumatera Barat: n=1004, MAPE=0.0314
# [80/20] Tepung Terigu (Curah) - Sumatera Selatan: n=1004, MAPE=0.0359
# [80/20] Tepung Terigu (Curah) - Sumatera Utara: n=1004, MAPE=0.0083
# Prediksi selesai! File 'final_rf.csv' telah dibuat 🚀
# Hasil MAPE telah disimpan ke 'mape_results_final_rf.xlsx'.

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings
import itertools
import os

warnings.filterwarnings("ignore")

# --- Asumsi: DataFrame train dan test sudah tersedia ---
# Contoh:
# train = pd.read_csv('data_train.csv')
# test = pd.read_csv('data_test.csv')

submission = test.copy()
submission['price'] = np.nan

mape_list = []

# Fungsi untuk mencari parameter SARIMA terbaik (dipangkas agar lebih cepat)
def sarimax_grid_search(train_series, seasonal_period=12):
    p = d = q = range(0, 2)  # Kurangi rentang
    P = D = Q = range(0, 1)  # Kurangi rentang
    s = [seasonal_period]
    
    best_aic = float("inf")
    best_order = None
    best_seasonal_order = None

    for order in itertools.product(p, d, q):
        for seasonal_order in itertools.product(P, D, Q, s):
            try:
                model = SARIMAX(train_series, order=order, seasonal_order=seasonal_order,
                                enforce_stationarity=False, enforce_invertibility=False)
                result = model.fit(disp=False)
                
                if result.aic < best_aic:
                    best_aic = result.aic
                    best_order = order
                    best_seasonal_order = seasonal_order
            except:
                continue
    
    return best_order, best_seasonal_order

# Loop berdasarkan kombinasi komoditas dan provinsi
for (komoditas, provinsi), group in train.groupby(['komoditas', 'provinsi']):
    train_data = group.sort_values('Date')
    test_data = test[(test['komoditas'] == komoditas) & (test['provinsi'] == provinsi)].sort_values('Date')
    
    if len(train_data) < 30:
        print(f"Data terlalu sedikit untuk {komoditas} - {provinsi}, skip...")
        continue
    
    n = len(train_data)
    split_idx = int(n * 0.8)
    if split_idx < 1 or split_idx == n:
        print(f"Data untuk {komoditas} - {provinsi} tidak cukup untuk split 80/20.")
        continue
    
    train_eval = train_data.iloc[:split_idx]
    val_eval = train_data.iloc[split_idx:]
    
    try:
        # Gunakan grid search dengan parameter lebih kecil
        best_order, best_seasonal_order = sarimax_grid_search(train_eval['harga'])

        # Model evaluasi
        model_eval = SARIMAX(train_eval['harga'], order=best_order, seasonal_order=best_seasonal_order,
                             enforce_stationarity=False, enforce_invertibility=False)
        model_fit_eval = model_eval.fit(disp=False)
        forecast_eval = model_fit_eval.forecast(steps=len(val_eval))
        
        actual = val_eval['harga'].values
        pred_eval = forecast_eval.values
        mape = np.mean(np.abs((actual - pred_eval) / actual))
        
        mape_list.append({
            'komoditas': komoditas,
            'provinsi': provinsi,
            'n_data': n,
            'mape': mape
        })
        print(f"[80/20] {komoditas} - {provinsi}: n={n}, MAPE={mape:.4f}")
    except Exception as e:
        print(f"Gagal evaluasi {komoditas} - {provinsi}: {e}")
        continue
    
    try:
        # Model final
        model_final = SARIMAX(train_data['harga'], order=best_order, seasonal_order=best_seasonal_order,
                              enforce_stationarity=False, enforce_invertibility=False)
        model_fit_final = model_final.fit(disp=False)
        forecast_final = model_fit_final.forecast(steps=len(test_data))
        
        submission.loc[test_data.index, 'price'] = forecast_final.values
    except Exception as e:
        print(f"Gagal proses final {komoditas} - {provinsi}: {e}")
        continue

submission = submission.drop(columns=['provinsi', 'komoditas', 'Date'])
submission.to_csv('final_sarimax_fast.csv', index=False)
print("Prediksi selesai! File 'final_sarimax_fast.csv' telah dibuat 🚀")

# Simpan hasil MAPE ke file Excel
df_mape = pd.DataFrame(mape_list)
if not df_mape.empty:
    overall_avg_mape = df_mape['mape'].mean()
else:
    overall_avg_mape = None

df_overall = pd.DataFrame({
    'overall_avg_mape': [overall_avg_mape],
    'n_models': [len(df_mape)]
})

with pd.ExcelWriter('mape_results_final_sarimax.xlsx') as writer:
    df_mape.to_excel(writer, sheet_name='MAPE_Detail', index=False)
    df_overall.to_excel(writer, sheet_name='MAPE_Overall', index=False)

print("Hasil MAPE telah disimpan ke 'mape_results_final_sarimax_fast.xlsx'.")
# Out:
# [80/20] Bawang Merah - Aceh: n=1004, MAPE=0.2994
# [80/20] Bawang Merah - Bali: n=1004, MAPE=0.2086
# [80/20] Bawang Merah - Banten: n=1004, MAPE=0.2242
# [80/20] Bawang Merah - Bengkulu: n=1004, MAPE=0.2795
# [80/20] Bawang Merah - DI Yogyakarta: n=1004, MAPE=0.3083
# [80/20] Bawang Merah - DKI Jakarta: n=1004, MAPE=0.2136
# [80/20] Bawang Merah - Gorontalo: n=1004, MAPE=0.2089
# [80/20] Bawang Merah - Jambi: n=1004, MAPE=0.2565
# [80/20] Bawang Merah - Jawa Barat: n=1004, MAPE=0.2276
# [80/20] Bawang Merah - Jawa Tengah: n=1004, MAPE=0.2654
# [80/20] Bawang Merah - Jawa Timur: n=1004, MAPE=0.2733
# [80/20] Bawang Merah - Kalimantan Barat: n=1004, MAPE=0.1483
# [80/20] Bawang Merah - Kalimantan Selatan: n=1004, MAPE=0.2193
# [80/20] Bawang Merah - Kalimantan Tengah: n=1004, MAPE=0.2004
# [80/20] Bawang Merah - Kalimantan Timur: n=1004, MAPE=0.1614
# [80/20] Bawang Merah - Kalimantan Utara: n=1004, MAPE=0.1596
# [80/20] Bawang Merah - Kepulauan Bangka Belitung: n=1004, MAPE=0.2523
# [80/20] Bawang Merah - Kepulauan Riau: n=1004, MAPE=0.0703
# [80/20] Bawang Merah - Lampung: n=1004, MAPE=0.2941
# [80/20] Bawang Merah - Maluku: n=1004, MAPE=0.1503
# [80/20] Bawang Merah - Maluku Utara: n=1004, MAPE=0.0827
# [80/20] Bawang Merah - Nusa Tenggara Barat: n=1004, MAPE=0.3463
# [80/20] Bawang Merah - Nusa Tenggara Timur: n=1004, MAPE=0.3009
# [80/20] Bawang Merah - Papua: n=1004, MAPE=0.0710
# [80/20] Bawang Merah - Papua Barat: n=1004, MAPE=0.0668
# [80/20] Bawang Merah - Riau: n=1004, MAPE=0.2506
# [80/20] Bawang Merah - Sulawesi Barat: n=1004, MAPE=0.1940
# [80/20] Bawang Merah - Sulawesi Selatan: n=1004, MAPE=0.1949
# [80/20] Bawang Merah - Sulawesi Tengah: n=1004, MAPE=0.1851
# [80/20] Bawang Merah - Sulawesi Tenggara: n=1004, MAPE=0.2044
# [80/20] Bawang Merah - Sulawesi Utara: n=1004, MAPE=0.1744
# [80/20] Bawang Merah - Sumatera Barat: n=1004, MAPE=0.3078
# [80/20] Bawang Merah - Sumatera Selatan: n=1004, MAPE=0.2847
# [80/20] Bawang Merah - Sumatera Utara: n=1004, MAPE=0.2592
# [80/20] Bawang Putih Bonggol - Aceh: n=1004, MAPE=0.0228
# [80/20] Bawang Putih Bonggol - Bali: n=1004, MAPE=0.0334
# [80/20] Bawang Putih Bonggol - Banten: n=1004, MAPE=0.0608
# [80/20] Bawang Putih Bonggol - Bengkulu: n=1004, MAPE=0.0547
# [80/20] Bawang Putih Bonggol - DI Yogyakarta: n=1004, MAPE=0.0276
# [80/20] Bawang Putih Bonggol - DKI Jakarta: n=1004, MAPE=0.0621
# [80/20] Bawang Putih Bonggol - Gorontalo: n=1004, MAPE=0.0815
# [80/20] Bawang Putih Bonggol - Jambi: n=1004, MAPE=0.0362
# [80/20] Bawang Putih Bonggol - Jawa Barat: n=1004, MAPE=0.0397
# [80/20] Bawang Putih Bonggol - Jawa Tengah: n=1004, MAPE=0.0287
# [80/20] Bawang Putih Bonggol - Jawa Timur: n=1004, MAPE=0.0270
# [80/20] Bawang Putih Bonggol - Kalimantan Barat: n=1004, MAPE=0.0644
# [80/20] Bawang Putih Bonggol - Kalimantan Selatan: n=1004, MAPE=0.0368
# [80/20] Bawang Putih Bonggol - Kalimantan Tengah: n=1004, MAPE=0.0426
# [80/20] Bawang Putih Bonggol - Kalimantan Timur: n=1004, MAPE=0.0415
# [80/20] Bawang Putih Bonggol - Kalimantan Utara: n=1004, MAPE=0.0505
# [80/20] Bawang Putih Bonggol - Kepulauan Bangka Belitung: n=1004, MAPE=0.0584
# [80/20] Bawang Putih Bonggol - Kepulauan Riau: n=1004, MAPE=0.0581
# [80/20] Bawang Putih Bonggol - Lampung: n=1004, MAPE=0.0512
# [80/20] Bawang Putih Bonggol - Maluku: n=1004, MAPE=0.0442
# [80/20] Bawang Putih Bonggol - Maluku Utara: n=1004, MAPE=0.0383
# [80/20] Bawang Putih Bonggol - Nusa Tenggara Barat: n=1004, MAPE=0.0371
# [80/20] Bawang Putih Bonggol - Nusa Tenggara Timur: n=1004, MAPE=0.0560
# [80/20] Bawang Putih Bonggol - Papua: n=1004, MAPE=0.0355
# [80/20] Bawang Putih Bonggol - Papua Barat: n=1004, MAPE=0.0380
# [80/20] Bawang Putih Bonggol - Riau: n=1004, MAPE=0.0308
# [80/20] Bawang Putih Bonggol - Sulawesi Barat: n=1004, MAPE=0.0324
# [80/20] Bawang Putih Bonggol - Sulawesi Selatan: n=1004, MAPE=0.0211
# [80/20] Bawang Putih Bonggol - Sulawesi Tengah: n=1004, MAPE=0.0442
# [80/20] Bawang Putih Bonggol - Sulawesi Tenggara: n=1004, MAPE=0.0562
# [80/20] Bawang Putih Bonggol - Sulawesi Utara: n=1004, MAPE=0.1170
# [80/20] Bawang Putih Bonggol - Sumatera Barat: n=1004, MAPE=0.0182
# [80/20] Bawang Putih Bonggol - Sumatera Selatan: n=1004, MAPE=0.0506
# [80/20] Bawang Putih Bonggol - Sumatera Utara: n=1004, MAPE=0.0274
# [80/20] Beras Medium - Aceh: n=1004, MAPE=0.0077
# [80/20] Beras Medium - Bali: n=1004, MAPE=0.0759
# [80/20] Beras Medium - Banten: n=1004, MAPE=0.1324
# [80/20] Beras Medium - Bengkulu: n=1004, MAPE=0.0336
# [80/20] Beras Medium - DI Yogyakarta: n=1004, MAPE=0.1248
# [80/20] Beras Medium - DKI Jakarta: n=1004, MAPE=0.0565
# [80/20] Beras Medium - Gorontalo: n=1004, MAPE=0.2619
# [80/20] Beras Medium - Jambi: n=1004, MAPE=0.0340
# [80/20] Beras Medium - Jawa Barat: n=1004, MAPE=0.1286
# [80/20] Beras Medium - Jawa Tengah: n=1004, MAPE=0.1135
# [80/20] Beras Medium - Jawa Timur: n=1004, MAPE=0.0294
# [80/20] Beras Medium - Kalimantan Barat: n=1004, MAPE=0.0086
# [80/20] Beras Medium - Kalimantan Selatan: n=1004, MAPE=0.0273
# [80/20] Beras Medium - Kalimantan Tengah: n=1004, MAPE=0.0259
# [80/20] Beras Medium - Kalimantan Timur: n=1004, MAPE=0.0263
# [80/20] Beras Medium - Kalimantan Utara: n=1004, MAPE=0.0139
# [80/20] Beras Medium - Kepulauan Bangka Belitung: n=1004, MAPE=0.0471
# [80/20] Beras Medium - Kepulauan Riau: n=1004, MAPE=0.0120
# [80/20] Beras Medium - Lampung: n=1004, MAPE=0.0973
# [80/20] Beras Medium - Maluku: n=1004, MAPE=0.0118
# [80/20] Beras Medium - Maluku Utara: n=1004, MAPE=0.0298
# [80/20] Beras Medium - Nusa Tenggara Barat: n=1004, MAPE=0.1023
# [80/20] Beras Medium - Nusa Tenggara Timur: n=1004, MAPE=0.1147
# [80/20] Beras Medium - Papua: n=1004, MAPE=0.0301
# [80/20] Beras Medium - Papua Barat: n=1004, MAPE=0.0220
# [80/20] Beras Medium - Riau: n=1004, MAPE=0.0166
# [80/20] Beras Medium - Sulawesi Barat: n=1004, MAPE=0.1149
# [80/20] Beras Medium - Sulawesi Selatan: n=1004, MAPE=0.1662
# [80/20] Beras Medium - Sulawesi Tengah: n=1004, MAPE=0.0838
# [80/20] Beras Medium - Sulawesi Tenggara: n=1004, MAPE=0.0785
# [80/20] Beras Medium - Sulawesi Utara: n=1004, MAPE=0.1039
# [80/20] Beras Medium - Sumatera Barat: n=1004, MAPE=0.0183
# [80/20] Beras Medium - Sumatera Selatan: n=1004, MAPE=0.0755
# [80/20] Beras Medium - Sumatera Utara: n=1004, MAPE=0.0109
# [80/20] Beras Premium - Aceh: n=1004, MAPE=0.0062
# [80/20] Beras Premium - Bali: n=1004, MAPE=0.0655
# [80/20] Beras Premium - Banten: n=1004, MAPE=0.0854
# [80/20] Beras Premium - Bengkulu: n=1004, MAPE=0.0940
# [80/20] Beras Premium - DI Yogyakarta: n=1004, MAPE=0.1048
# [80/20] Beras Premium - DKI Jakarta: n=1004, MAPE=0.0620
# [80/20] Beras Premium - Gorontalo: n=1004, MAPE=0.1963
# [80/20] Beras Premium - Jambi: n=1004, MAPE=0.0223
# [80/20] Beras Premium - Jawa Barat: n=1004, MAPE=0.0813
# [80/20] Beras Premium - Jawa Tengah: n=1004, MAPE=0.1293
# [80/20] Beras Premium - Jawa Timur: n=1004, MAPE=0.0519
# [80/20] Beras Premium - Kalimantan Barat: n=1004, MAPE=0.0109
# [80/20] Beras Premium - Kalimantan Selatan: n=1004, MAPE=0.0182
# [80/20] Beras Premium - Kalimantan Tengah: n=1004, MAPE=0.0372
# [80/20] Beras Premium - Kalimantan Timur: n=1004, MAPE=0.0283
# [80/20] Beras Premium - Kalimantan Utara: n=1004, MAPE=0.0079
# [80/20] Beras Premium - Kepulauan Bangka Belitung: n=1004, MAPE=0.0687
# [80/20] Beras Premium - Kepulauan Riau: n=1004, MAPE=0.0163
# [80/20] Beras Premium - Lampung: n=1004, MAPE=0.0792
# [80/20] Beras Premium - Maluku: n=1004, MAPE=0.0096
# [80/20] Beras Premium - Maluku Utara: n=1004, MAPE=0.0053
# [80/20] Beras Premium - Nusa Tenggara Barat: n=1004, MAPE=0.1216
# [80/20] Beras Premium - Nusa Tenggara Timur: n=1004, MAPE=0.0746
# [80/20] Beras Premium - Papua: n=1004, MAPE=0.0080
# [80/20] Beras Premium - Papua Barat: n=1004, MAPE=0.0125
# [80/20] Beras Premium - Riau: n=1004, MAPE=0.0175
# [80/20] Beras Premium - Sulawesi Barat: n=1004, MAPE=0.0845
# [80/20] Beras Premium - Sulawesi Selatan: n=1004, MAPE=0.1429
# [80/20] Beras Premium - Sulawesi Tengah: n=1004, MAPE=0.0664
# [80/20] Beras Premium - Sulawesi Tenggara: n=1004, MAPE=0.1348
# [80/20] Beras Premium - Sulawesi Utara: n=1004, MAPE=0.1046
# [80/20] Beras Premium - Sumatera Barat: n=1004, MAPE=0.0069
# [80/20] Beras Premium - Sumatera Selatan: n=1004, MAPE=0.0408
# [80/20] Beras Premium - Sumatera Utara: n=1004, MAPE=0.0072
# [80/20] Cabai Merah Keriting - Aceh: n=1004, MAPE=0.6083
# [80/20] Cabai Merah Keriting - Bali: n=1004, MAPE=0.8722
# [80/20] Cabai Merah Keriting - Banten: n=1004, MAPE=0.8814
# [80/20] Cabai Merah Keriting - Bengkulu: n=1004, MAPE=0.5601
# [80/20] Cabai Merah Keriting - DI Yogyakarta: n=1004, MAPE=0.6811
# [80/20] Cabai Merah Keriting - DKI Jakarta: n=1004, MAPE=0.7850
# [80/20] Cabai Merah Keriting - Gorontalo: n=1004, MAPE=0.2448
# [80/20] Cabai Merah Keriting - Jambi: n=1004, MAPE=1.1345
# [80/20] Cabai Merah Keriting - Jawa Barat: n=1004, MAPE=0.8435
# [80/20] Cabai Merah Keriting - Jawa Tengah: n=1004, MAPE=0.8159
# [80/20] Cabai Merah Keriting - Jawa Timur: n=1004, MAPE=0.5594
# [80/20] Cabai Merah Keriting - Kalimantan Barat: n=1004, MAPE=0.1163
# [80/20] Cabai Merah Keriting - Kalimantan Selatan: n=1004, MAPE=0.7220
# [80/20] Cabai Merah Keriting - Kalimantan Tengah: n=1004, MAPE=0.3112
# [80/20] Cabai Merah Keriting - Kalimantan Timur: n=1004, MAPE=0.3418
# [80/20] Cabai Merah Keriting - Kalimantan Utara: n=1004, MAPE=0.1563
# [80/20] Cabai Merah Keriting - Kepulauan Bangka Belitung: n=1004, MAPE=0.5466
# [80/20] Cabai Merah Keriting - Kepulauan Riau: n=1004, MAPE=0.3759
# [80/20] Cabai Merah Keriting - Lampung: n=1004, MAPE=0.8369
# [80/20] Cabai Merah Keriting - Maluku: n=1004, MAPE=0.1290
# [80/20] Cabai Merah Keriting - Maluku Utara: n=1004, MAPE=0.1706
# [80/20] Cabai Merah Keriting - Nusa Tenggara Barat: n=1004, MAPE=0.7662
# [80/20] Cabai Merah Keriting - Nusa Tenggara Timur: n=1004, MAPE=0.1200
# [80/20] Cabai Merah Keriting - Papua: n=1004, MAPE=0.2019
# [80/20] Cabai Merah Keriting - Papua Barat: n=1004, MAPE=0.2038
# [80/20] Cabai Merah Keriting - Riau: n=1004, MAPE=0.7022
# [80/20] Cabai Merah Keriting - Sulawesi Barat: n=1004, MAPE=0.6461
# [80/20] Cabai Merah Keriting - Sulawesi Selatan: n=1004, MAPE=0.6243
# [80/20] Cabai Merah Keriting - Sulawesi Tengah: n=1004, MAPE=0.1608
# [80/20] Cabai Merah Keriting - Sulawesi Tenggara: n=1004, MAPE=0.2005
# [80/20] Cabai Merah Keriting - Sulawesi Utara: n=1004, MAPE=0.3179
# [80/20] Cabai Merah Keriting - Sumatera Barat: n=1004, MAPE=0.8669
# [80/20] Cabai Merah Keriting - Sumatera Selatan: n=1004, MAPE=0.6775
# [80/20] Cabai Merah Keriting - Sumatera Utara: n=1004, MAPE=1.1543
# [80/20] Cabai Rawit Merah - Aceh: n=1004, MAPE=0.3502
# [80/20] Cabai Rawit Merah - Bali: n=1004, MAPE=0.8184
# [80/20] Cabai Rawit Merah - Banten: n=1004, MAPE=0.5608
# [80/20] Cabai Rawit Merah - Bengkulu: n=1004, MAPE=0.3597
# [80/20] Cabai Rawit Merah - DI Yogyakarta: n=1004, MAPE=0.4630
# [80/20] Cabai Rawit Merah - DKI Jakarta: n=1004, MAPE=0.4636
# [80/20] Cabai Rawit Merah - Gorontalo: n=1004, MAPE=0.2496
# [80/20] Cabai Rawit Merah - Jambi: n=1004, MAPE=0.5213
# [80/20] Cabai Rawit Merah - Jawa Barat: n=1004, MAPE=0.5702
# [80/20] Cabai Rawit Merah - Jawa Tengah: n=1004, MAPE=0.6760
# [80/20] Cabai Rawit Merah - Jawa Timur: n=1004, MAPE=0.5573
# [80/20] Cabai Rawit Merah - Kalimantan Barat: n=1004, MAPE=0.1326
# [80/20] Cabai Rawit Merah - Kalimantan Selatan: n=1004, MAPE=0.4706
# [80/20] Cabai Rawit Merah - Kalimantan Tengah: n=1004, MAPE=0.3413
# [80/20] Cabai Rawit Merah - Kalimantan Timur: n=1004, MAPE=0.3991
# [80/20] Cabai Rawit Merah - Kalimantan Utara: n=1004, MAPE=0.1782
# [80/20] Cabai Rawit Merah - Kepulauan Bangka Belitung: n=1004, MAPE=0.4103
# [80/20] Cabai Rawit Merah - Kepulauan Riau: n=1004, MAPE=0.2747
# [80/20] Cabai Rawit Merah - Lampung: n=1004, MAPE=0.3414
# [80/20] Cabai Rawit Merah - Maluku: n=1004, MAPE=0.2473
# [80/20] Cabai Rawit Merah - Maluku Utara: n=1004, MAPE=0.1135
# [80/20] Cabai Rawit Merah - Nusa Tenggara Barat: n=1004, MAPE=0.4453
# [80/20] Cabai Rawit Merah - Nusa Tenggara Timur: n=1004, MAPE=0.2099
# [80/20] Cabai Rawit Merah - Papua: n=1004, MAPE=0.3297
# [80/20] Cabai Rawit Merah - Papua Barat: n=1004, MAPE=0.2016
# [80/20] Cabai Rawit Merah - Riau: n=1004, MAPE=0.3159
# [80/20] Cabai Rawit Merah - Sulawesi Barat: n=1004, MAPE=0.1065
# [80/20] Cabai Rawit Merah - Sulawesi Selatan: n=1004, MAPE=0.2604
# [80/20] Cabai Rawit Merah - Sulawesi Tengah: n=1004, MAPE=0.1576
# [80/20] Cabai Rawit Merah - Sulawesi Tenggara: n=1004, MAPE=0.1221
# [80/20] Cabai Rawit Merah - Sulawesi Utara: n=1004, MAPE=0.2682
# [80/20] Cabai Rawit Merah - Sumatera Barat: n=1004, MAPE=0.4316
# [80/20] Cabai Rawit Merah - Sumatera Selatan: n=1004, MAPE=0.5177
# [80/20] Cabai Rawit Merah - Sumatera Utara: n=1004, MAPE=0.2578
# [80/20] Daging Ayam Ras - Aceh: n=1004, MAPE=0.0812
# [80/20] Daging Ayam Ras - Bali: n=1004, MAPE=0.0186
# [80/20] Daging Ayam Ras - Banten: n=1004, MAPE=0.0627
# [80/20] Daging Ayam Ras - Bengkulu: n=1004, MAPE=0.1243
# [80/20] Daging Ayam Ras - DI Yogyakarta: n=1004, MAPE=0.0988
# [80/20] Daging Ayam Ras - DKI Jakarta: n=1004, MAPE=0.0363
# [80/20] Daging Ayam Ras - Gorontalo: n=1004, MAPE=0.1065
# [80/20] Daging Ayam Ras - Jambi: n=1004, MAPE=0.1546
# [80/20] Daging Ayam Ras - Jawa Barat: n=1004, MAPE=0.0913
# [80/20] Daging Ayam Ras - Jawa Tengah: n=1004, MAPE=0.0737
# [80/20] Daging Ayam Ras - Jawa Timur: n=1004, MAPE=0.1180
# [80/20] Daging Ayam Ras - Kalimantan Barat: n=1004, MAPE=0.0597
# [80/20] Daging Ayam Ras - Kalimantan Selatan: n=1004, MAPE=0.0793
# [80/20] Daging Ayam Ras - Kalimantan Tengah: n=1004, MAPE=0.0739
# [80/20] Daging Ayam Ras - Kalimantan Timur: n=1004, MAPE=0.0580
# [80/20] Daging Ayam Ras - Kalimantan Utara: n=1004, MAPE=0.0395
# [80/20] Daging Ayam Ras - Kepulauan Bangka Belitung: n=1004, MAPE=0.0333
# [80/20] Daging Ayam Ras - Kepulauan Riau: n=1004, MAPE=0.0184
# [80/20] Daging Ayam Ras - Lampung: n=1004, MAPE=0.0450
# [80/20] Daging Ayam Ras - Maluku: n=1004, MAPE=0.0273
# [80/20] Daging Ayam Ras - Maluku Utara: n=1004, MAPE=0.0180
# [80/20] Daging Ayam Ras - Nusa Tenggara Barat: n=1004, MAPE=0.0496
# [80/20] Daging Ayam Ras - Nusa Tenggara Timur: n=1004, MAPE=0.0172
# [80/20] Daging Ayam Ras - Papua: n=1004, MAPE=0.0787
# [80/20] Daging Ayam Ras - Papua Barat: n=1004, MAPE=0.0301
# [80/20] Daging Ayam Ras - Riau: n=1004, MAPE=0.1579
# [80/20] Daging Ayam Ras - Sulawesi Barat: n=1004, MAPE=0.0414
# [80/20] Daging Ayam Ras - Sulawesi Selatan: n=1004, MAPE=0.1048
# [80/20] Daging Ayam Ras - Sulawesi Tengah: n=1004, MAPE=0.0645
# [80/20] Daging Ayam Ras - Sulawesi Tenggara: n=1004, MAPE=0.0702
# [80/20] Daging Ayam Ras - Sulawesi Utara: n=1004, MAPE=0.0707
# [80/20] Daging Ayam Ras - Sumatera Barat: n=1004, MAPE=0.0641
# [80/20] Daging Ayam Ras - Sumatera Selatan: n=1004, MAPE=0.1323
# [80/20] Daging Ayam Ras - Sumatera Utara: n=1004, MAPE=0.1541
# [80/20] Daging Sapi Murni - Aceh: n=1004, MAPE=0.0136
# [80/20] Daging Sapi Murni - Bali: n=1004, MAPE=0.0112
# [80/20] Daging Sapi Murni - Banten: n=1004, MAPE=0.0138
# [80/20] Daging Sapi Murni - Bengkulu: n=1004, MAPE=0.0195
# [80/20] Daging Sapi Murni - DI Yogyakarta: n=1004, MAPE=0.0075
# [80/20] Daging Sapi Murni - DKI Jakarta: n=1004, MAPE=0.0178
# [80/20] Daging Sapi Murni - Gorontalo: n=1004, MAPE=0.0057
# [80/20] Daging Sapi Murni - Jambi: n=1004, MAPE=0.0320
# [80/20] Daging Sapi Murni - Jawa Barat: n=1004, MAPE=0.0201
# [80/20] Daging Sapi Murni - Jawa Tengah: n=1004, MAPE=0.0101
# [80/20] Daging Sapi Murni - Jawa Timur: n=1004, MAPE=0.0100
# [80/20] Daging Sapi Murni - Kalimantan Barat: n=1004, MAPE=0.0062
# [80/20] Daging Sapi Murni - Kalimantan Selatan: n=1004, MAPE=0.0083
# [80/20] Daging Sapi Murni - Kalimantan Tengah: n=1004, MAPE=0.0086
# [80/20] Daging Sapi Murni - Kalimantan Timur: n=1004, MAPE=0.0106
# [80/20] Daging Sapi Murni - Kalimantan Utara: n=1004, MAPE=0.0373
# [80/20] Daging Sapi Murni - Kepulauan Bangka Belitung: n=1004, MAPE=0.0097
# [80/20] Daging Sapi Murni - Kepulauan Riau: n=1004, MAPE=0.0138
# [80/20] Daging Sapi Murni - Lampung: n=1004, MAPE=0.0128
# [80/20] Daging Sapi Murni - Maluku: n=1004, MAPE=0.0232
# [80/20] Daging Sapi Murni - Maluku Utara: n=1004, MAPE=0.0247
# [80/20] Daging Sapi Murni - Nusa Tenggara Barat: n=1004, MAPE=0.0082
# [80/20] Daging Sapi Murni - Nusa Tenggara Timur: n=1004, MAPE=0.0073
# [80/20] Daging Sapi Murni - Papua: n=1004, MAPE=0.0121
# [80/20] Daging Sapi Murni - Papua Barat: n=1004, MAPE=0.0315
# [80/20] Daging Sapi Murni - Riau: n=1004, MAPE=0.0190
# [80/20] Daging Sapi Murni - Sulawesi Barat: n=1004, MAPE=0.0063
# [80/20] Daging Sapi Murni - Sulawesi Selatan: n=1004, MAPE=0.0041
# [80/20] Daging Sapi Murni - Sulawesi Tengah: n=1004, MAPE=0.0111
# [80/20] Daging Sapi Murni - Sulawesi Tenggara: n=1004, MAPE=0.0064
# [80/20] Daging Sapi Murni - Sulawesi Utara: n=1004, MAPE=0.0114
# [80/20] Daging Sapi Murni - Sumatera Barat: n=1004, MAPE=0.0148
# [80/20] Daging Sapi Murni - Sumatera Selatan: n=1004, MAPE=0.0095
# [80/20] Daging Sapi Murni - Sumatera Utara: n=1004, MAPE=0.0149
# [80/20] Gula Konsumsi - Aceh: n=1004, MAPE=0.0363
# [80/20] Gula Konsumsi - Bali: n=1004, MAPE=0.0090
# [80/20] Gula Konsumsi - Banten: n=1004, MAPE=0.0411
# [80/20] Gula Konsumsi - Bengkulu: n=1004, MAPE=0.0227
# [80/20] Gula Konsumsi - DI Yogyakarta: n=1004, MAPE=0.0224
# [80/20] Gula Konsumsi - DKI Jakarta: n=1004, MAPE=0.0985
# [80/20] Gula Konsumsi - Gorontalo: n=1004, MAPE=0.0264
# [80/20] Gula Konsumsi - Jambi: n=1004, MAPE=0.0227
# [80/20] Gula Konsumsi - Jawa Barat: n=1004, MAPE=0.0154
# [80/20] Gula Konsumsi - Jawa Tengah: n=1004, MAPE=0.0138
# [80/20] Gula Konsumsi - Jawa Timur: n=1004, MAPE=0.0177
# [80/20] Gula Konsumsi - Kalimantan Barat: n=1004, MAPE=0.0138
# [80/20] Gula Konsumsi - Kalimantan Selatan: n=1004, MAPE=0.0187
# [80/20] Gula Konsumsi - Kalimantan Tengah: n=1004, MAPE=0.0390
# [80/20] Gula Konsumsi - Kalimantan Timur: n=1004, MAPE=0.0215
# [80/20] Gula Konsumsi - Kalimantan Utara: n=1004, MAPE=0.0090
# [80/20] Gula Konsumsi - Kepulauan Bangka Belitung: n=1004, MAPE=0.0099
# [80/20] Gula Konsumsi - Kepulauan Riau: n=1004, MAPE=0.0144
# [80/20] Gula Konsumsi - Lampung: n=1004, MAPE=0.0222
# [80/20] Gula Konsumsi - Maluku: n=1004, MAPE=0.0180
# [80/20] Gula Konsumsi - Maluku Utara: n=1004, MAPE=0.0160
# [80/20] Gula Konsumsi - Nusa Tenggara Barat: n=1004, MAPE=0.0133
# [80/20] Gula Konsumsi - Nusa Tenggara Timur: n=1004, MAPE=0.0224
# [80/20] Gula Konsumsi - Papua: n=1004, MAPE=0.0319
# [80/20] Gula Konsumsi - Papua Barat: n=1004, MAPE=0.0467
# [80/20] Gula Konsumsi - Riau: n=1004, MAPE=0.0148
# [80/20] Gula Konsumsi - Sulawesi Barat: n=1004, MAPE=0.0128
# [80/20] Gula Konsumsi - Sulawesi Selatan: n=1004, MAPE=0.0297
# [80/20] Gula Konsumsi - Sulawesi Tengah: n=1004, MAPE=0.0093
# [80/20] Gula Konsumsi - Sulawesi Tenggara: n=1004, MAPE=0.0239
# [80/20] Gula Konsumsi - Sulawesi Utara: n=1004, MAPE=0.0166
# [80/20] Gula Konsumsi - Sumatera Barat: n=1004, MAPE=0.0180
# [80/20] Gula Konsumsi - Sumatera Selatan: n=1004, MAPE=0.0262
# [80/20] Gula Konsumsi - Sumatera Utara: n=1004, MAPE=0.0087
# [80/20] Minyak Goreng Curah - Aceh: n=1004, MAPE=0.0192
# [80/20] Minyak Goreng Curah - Bali: n=1004, MAPE=0.0425
# [80/20] Minyak Goreng Curah - Banten: n=1004, MAPE=0.0390
# [80/20] Minyak Goreng Curah - Bengkulu: n=1004, MAPE=0.0088
# [80/20] Minyak Goreng Curah - DI Yogyakarta: n=1004, MAPE=0.0402
# [80/20] Minyak Goreng Curah - DKI Jakarta: n=1004, MAPE=0.0477
# [80/20] Minyak Goreng Curah - Gorontalo: n=1004, MAPE=0.0880
# [80/20] Minyak Goreng Curah - Jambi: n=1004, MAPE=0.0246
# [80/20] Minyak Goreng Curah - Jawa Barat: n=1004, MAPE=0.0471
# [80/20] Minyak Goreng Curah - Jawa Tengah: n=1004, MAPE=0.0379
# [80/20] Minyak Goreng Curah - Jawa Timur: n=1004, MAPE=0.0349
# [80/20] Minyak Goreng Curah - Kalimantan Barat: n=1004, MAPE=0.0206
# [80/20] Minyak Goreng Curah - Kalimantan Selatan: n=1004, MAPE=0.0412
# [80/20] Minyak Goreng Curah - Kalimantan Tengah: n=1004, MAPE=0.0110
# [80/20] Minyak Goreng Curah - Kalimantan Timur: n=1004, MAPE=0.0248
# [80/20] Minyak Goreng Curah - Kalimantan Utara: n=1004, MAPE=0.0371
# [80/20] Minyak Goreng Curah - Kepulauan Bangka Belitung: n=1004, MAPE=0.0211
# [80/20] Minyak Goreng Curah - Kepulauan Riau: n=1004, MAPE=0.0233
# [80/20] Minyak Goreng Curah - Lampung: n=1004, MAPE=0.0362
# [80/20] Minyak Goreng Curah - Maluku: n=1004, MAPE=0.0701
# [80/20] Minyak Goreng Curah - Maluku Utara: n=1004, MAPE=0.0794
# [80/20] Minyak Goreng Curah - Nusa Tenggara Barat: n=1004, MAPE=0.0142
# [80/20] Minyak Goreng Curah - Nusa Tenggara Timur: n=1004, MAPE=0.0284
# [80/20] Minyak Goreng Curah - Papua: n=1004, MAPE=0.0226
# [80/20] Minyak Goreng Curah - Papua Barat: n=1004, MAPE=0.0282
# [80/20] Minyak Goreng Curah - Riau: n=1004, MAPE=0.0149
# [80/20] Minyak Goreng Curah - Sulawesi Barat: n=1004, MAPE=0.0193
# [80/20] Minyak Goreng Curah - Sulawesi Selatan: n=1004, MAPE=0.0232
# [80/20] Minyak Goreng Curah - Sulawesi Tengah: n=1004, MAPE=0.0143
# [80/20] Minyak Goreng Curah - Sulawesi Tenggara: n=1004, MAPE=0.0179
# [80/20] Minyak Goreng Curah - Sulawesi Utara: n=1004, MAPE=0.0203
# [80/20] Minyak Goreng Curah - Sumatera Barat: n=1004, MAPE=0.0072
# [80/20] Minyak Goreng Curah - Sumatera Selatan: n=1004, MAPE=0.0101
# [80/20] Minyak Goreng Curah - Sumatera Utara: n=1004, MAPE=0.0344
# [80/20] Minyak Goreng Kemasan Sederhana - Aceh: n=1004, MAPE=0.0146
# [80/20] Minyak Goreng Kemasan Sederhana - Bali: n=1004, MAPE=0.0337
# [80/20] Minyak Goreng Kemasan Sederhana - Banten: n=1004, MAPE=0.0535
# [80/20] Minyak Goreng Kemasan Sederhana - Bengkulu: n=1004, MAPE=0.0244
# [80/20] Minyak Goreng Kemasan Sederhana - DI Yogyakarta: n=1004, MAPE=0.0140
# [80/20] Minyak Goreng Kemasan Sederhana - DKI Jakarta: n=1004, MAPE=0.0198
# [80/20] Minyak Goreng Kemasan Sederhana - Gorontalo: n=1004, MAPE=0.0218
# [80/20] Minyak Goreng Kemasan Sederhana - Jambi: n=1004, MAPE=0.0208
# [80/20] Minyak Goreng Kemasan Sederhana - Jawa Barat: n=1004, MAPE=0.0106
# [80/20] Minyak Goreng Kemasan Sederhana - Jawa Tengah: n=1004, MAPE=0.0206
# [80/20] Minyak Goreng Kemasan Sederhana - Jawa Timur: n=1004, MAPE=0.0213
# [80/20] Minyak Goreng Kemasan Sederhana - Kalimantan Barat: n=1004, MAPE=0.0105
# [80/20] Minyak Goreng Kemasan Sederhana - Kalimantan Selatan: n=1004, MAPE=0.0179
# [80/20] Minyak Goreng Kemasan Sederhana - Kalimantan Tengah: n=1004, MAPE=0.0119
# [80/20] Minyak Goreng Kemasan Sederhana - Kalimantan Timur: n=1004, MAPE=0.0184
# [80/20] Minyak Goreng Kemasan Sederhana - Kalimantan Utara: n=1004, MAPE=0.0194
# [80/20] Minyak Goreng Kemasan Sederhana - Kepulauan Bangka Belitung: n=1004, MAPE=0.0185
# [80/20] Minyak Goreng Kemasan Sederhana - Kepulauan Riau: n=1004, MAPE=0.0214
# [80/20] Minyak Goreng Kemasan Sederhana - Lampung: n=1004, MAPE=0.0163
# [80/20] Minyak Goreng Kemasan Sederhana - Maluku: n=1004, MAPE=0.0176
# [80/20] Minyak Goreng Kemasan Sederhana - Maluku Utara: n=1004, MAPE=0.0154
# [80/20] Minyak Goreng Kemasan Sederhana - Nusa Tenggara Barat: n=1004, MAPE=0.0321
# [80/20] Minyak Goreng Kemasan Sederhana - Nusa Tenggara Timur: n=1004, MAPE=0.0102
# [80/20] Minyak Goreng Kemasan Sederhana - Papua: n=1004, MAPE=0.0185
# [80/20] Minyak Goreng Kemasan Sederhana - Papua Barat: n=1004, MAPE=0.0304
# [80/20] Minyak Goreng Kemasan Sederhana - Riau: n=1004, MAPE=0.0142
# [80/20] Minyak Goreng Kemasan Sederhana - Sulawesi Barat: n=1004, MAPE=0.0138
# [80/20] Minyak Goreng Kemasan Sederhana - Sulawesi Selatan: n=1004, MAPE=0.0248
# [80/20] Minyak Goreng Kemasan Sederhana - Sulawesi Tengah: n=1004, MAPE=0.0234
# [80/20] Minyak Goreng Kemasan Sederhana - Sulawesi Tenggara: n=1004, MAPE=0.0201
# [80/20] Minyak Goreng Kemasan Sederhana - Sulawesi Utara: n=1004, MAPE=0.0096
# [80/20] Minyak Goreng Kemasan Sederhana - Sumatera Barat: n=1004, MAPE=0.0137
# [80/20] Minyak Goreng Kemasan Sederhana - Sumatera Selatan: n=1004, MAPE=0.0173
# [80/20] Minyak Goreng Kemasan Sederhana - Sumatera Utara: n=1004, MAPE=0.0283
# [80/20] Telur Ayam Ras - Aceh: n=1004, MAPE=0.0607
# [80/20] Telur Ayam Ras - Bali: n=1004, MAPE=0.0448
# [80/20] Telur Ayam Ras - Banten: n=1004, MAPE=0.1011
# [80/20] Telur Ayam Ras - Bengkulu: n=1004, MAPE=0.0250
# [80/20] Telur Ayam Ras - DI Yogyakarta: n=1004, MAPE=0.1530
# [80/20] Telur Ayam Ras - DKI Jakarta: n=1004, MAPE=0.0971
# [80/20] Telur Ayam Ras - Gorontalo: n=1004, MAPE=0.1247
# [80/20] Telur Ayam Ras - Jambi: n=1004, MAPE=0.0294
# [80/20] Telur Ayam Ras - Jawa Barat: n=1004, MAPE=0.1910
# [80/20] Telur Ayam Ras - Jawa Tengah: n=1004, MAPE=0.1388
# [80/20] Telur Ayam Ras - Jawa Timur: n=1004, MAPE=0.1699
# [80/20] Telur Ayam Ras - Kalimantan Barat: n=1004, MAPE=0.0910
# [80/20] Telur Ayam Ras - Kalimantan Selatan: n=1004, MAPE=0.0720
# [80/20] Telur Ayam Ras - Kalimantan Tengah: n=1004, MAPE=0.0359
# [80/20] Telur Ayam Ras - Kalimantan Timur: n=1004, MAPE=0.0808
# [80/20] Telur Ayam Ras - Kalimantan Utara: n=1004, MAPE=0.0654
# [80/20] Telur Ayam Ras - Kepulauan Bangka Belitung: n=1004, MAPE=0.0344
# [80/20] Telur Ayam Ras - Kepulauan Riau: n=1004, MAPE=0.0464
# [80/20] Telur Ayam Ras - Lampung: n=1004, MAPE=0.0711
# [80/20] Telur Ayam Ras - Maluku: n=1004, MAPE=0.0274
# [80/20] Telur Ayam Ras - Maluku Utara: n=1004, MAPE=0.0320
# [80/20] Telur Ayam Ras - Nusa Tenggara Barat: n=1004, MAPE=0.0676
# [80/20] Telur Ayam Ras - Nusa Tenggara Timur: n=1004, MAPE=0.0430
# [80/20] Telur Ayam Ras - Papua: n=1004, MAPE=0.0154
# [80/20] Telur Ayam Ras - Papua Barat: n=1004, MAPE=0.0119
# [80/20] Telur Ayam Ras - Riau: n=1004, MAPE=0.0203
# [80/20] Telur Ayam Ras - Sulawesi Barat: n=1004, MAPE=0.1115
# [80/20] Telur Ayam Ras - Sulawesi Selatan: n=1004, MAPE=0.1216
# [80/20] Telur Ayam Ras - Sulawesi Tengah: n=1004, MAPE=0.0675
# [80/20] Telur Ayam Ras - Sulawesi Tenggara: n=1004, MAPE=0.1311
# [80/20] Telur Ayam Ras - Sulawesi Utara: n=1004, MAPE=0.0649
# [80/20] Telur Ayam Ras - Sumatera Barat: n=1004, MAPE=0.0280
# [80/20] Telur Ayam Ras - Sumatera Selatan: n=1004, MAPE=0.0925
# [80/20] Telur Ayam Ras - Sumatera Utara: n=1004, MAPE=0.0219
# [80/20] Tepung Terigu (Curah) - Aceh: n=1004, MAPE=0.0111
# [80/20] Tepung Terigu (Curah) - Bali: n=1004, MAPE=0.1040
# [80/20] Tepung Terigu (Curah) - Banten: n=1004, MAPE=0.0099
# [80/20] Tepung Terigu (Curah) - Bengkulu: n=1004, MAPE=0.0135
# [80/20] Tepung Terigu (Curah) - DI Yogyakarta: n=1004, MAPE=0.0552
# [80/20] Tepung Terigu (Curah) - DKI Jakarta: n=1004, MAPE=0.0107
# [80/20] Tepung Terigu (Curah) - Gorontalo: n=1004, MAPE=0.0246
# [80/20] Tepung Terigu (Curah) - Jambi: n=1004, MAPE=0.0100
# [80/20] Tepung Terigu (Curah) - Jawa Barat: n=1004, MAPE=0.0138
# [80/20] Tepung Terigu (Curah) - Jawa Tengah: n=1004, MAPE=0.0317
# [80/20] Tepung Terigu (Curah) - Jawa Timur: n=1004, MAPE=0.0207
# [80/20] Tepung Terigu (Curah) - Kalimantan Barat: n=1004, MAPE=0.0106
# [80/20] Tepung Terigu (Curah) - Kalimantan Selatan: n=1004, MAPE=0.0091
# [80/20] Tepung Terigu (Curah) - Kalimantan Tengah: n=1004, MAPE=0.0329
# [80/20] Tepung Terigu (Curah) - Kalimantan Timur: n=1004, MAPE=0.0367
# [80/20] Tepung Terigu (Curah) - Kalimantan Utara: n=1004, MAPE=0.0279
# [80/20] Tepung Terigu (Curah) - Kepulauan Bangka Belitung: n=1004, MAPE=0.0277
# [80/20] Tepung Terigu (Curah) - Kepulauan Riau: n=1004, MAPE=0.0344
# [80/20] Tepung Terigu (Curah) - Lampung: n=1004, MAPE=0.0130
# [80/20] Tepung Terigu (Curah) - Maluku: n=1004, MAPE=0.0280
# [80/20] Tepung Terigu (Curah) - Maluku Utara: n=1004, MAPE=0.0273
# [80/20] Tepung Terigu (Curah) - Nusa Tenggara Barat: n=1004, MAPE=0.0100
# [80/20] Tepung Terigu (Curah) - Nusa Tenggara Timur: n=1004, MAPE=0.0379
# [80/20] Tepung Terigu (Curah) - Papua: n=1004, MAPE=0.0063
# [80/20] Tepung Terigu (Curah) - Papua Barat: n=1004, MAPE=0.0189
# [80/20] Tepung Terigu (Curah) - Riau: n=1004, MAPE=0.0400
# [80/20] Tepung Terigu (Curah) - Sulawesi Barat: n=1004, MAPE=0.0188
# [80/20] Tepung Terigu (Curah) - Sulawesi Selatan: n=1004, MAPE=0.0103
# [80/20] Tepung Terigu (Curah) - Sulawesi Tengah: n=1004, MAPE=0.0194
# [80/20] Tepung Terigu (Curah) - Sulawesi Tenggara: n=1004, MAPE=0.0349
# [80/20] Tepung Terigu (Curah) - Sulawesi Utara: n=1004, MAPE=0.0219
# [80/20] Tepung Terigu (Curah) - Sumatera Barat: n=1004, MAPE=0.0311
# [80/20] Tepung Terigu (Curah) - Sumatera Selatan: n=1004, MAPE=0.0360
# [80/20] Tepung Terigu (Curah) - Sumatera Utara: n=1004, MAPE=0.0083
# Prediksi selesai! File 'final_sarimax_fast.csv' telah dibuat 🚀
# Hasil MAPE telah disimpan ke 'mape_results_final_sarimax_fast.xlsx'.

# %% [markdown]
# # SUBMISSION

# %%
import pandas as pd

# Load submission files
sub1 = pd.read_csv(r"D:\Data Sains\dataset\comodity-price-prediction-penyisihan-arkavidia-9\iris n\New\final_arima.csv")
sub2 = pd.read_csv(r"D:\Data Sains\dataset\comodity-price-prediction-penyisihan-arkavidia-9\iris n\New\final_sarimax_fast.csv")
sub3 = pd.read_csv(r"D:\Data Sains\dataset\comodity-price-prediction-penyisihan-arkavidia-9\iris n\New\final_xgb.csv")
sub4 = pd.read_csv(r"D:\Data Sains\dataset\comodity-price-prediction-penyisihan-arkavidia-9\iris n\New\final_rf.csv")

# Pastikan semua file memiliki kolom yang sama
assert sub1.columns.equals(sub2.columns) and sub1.columns.equals(sub3.columns) and sub1.columns.equals(sub4.columns), "Kolom submission tidak cocok!"

# Cek jumlah NaN sebelum ensemble
print(f"NaN sebelum ensemble:\n{sub1.isna().sum()}\n")

# Gabungkan hasil dengan rata-rata (mengabaikan NaN)
submission_final = sub1.copy()
submission_final['price'] = pd.concat([sub1['price'], sub2['price'], sub3['price'], sub4['price']], axis=1).mean(axis=1, skipna=True)

# Tangani nilai NaN setelah ensemble
if submission_final['price'].isna().sum() > 0:
    print("Terdapat NaN setelah ensemble, melakukan imputasi...")
    submission_final['price'] = submission_final['price'].fillna(method='ffill')  # Bisa juga .fillna(0) atau .fillna(submission_final['price'].median())

# Simpan hasil
submission_final.to_csv('submission_final_ensemble.csv', index=False)
print("FInal Ensemble submission berhasil dibuat! 🚀")
# Out:
# NaN sebelum ensemble:
# id       0
# price    0
# dtype: int64
#
# FInal Ensemble submission berhasil dibuat! 🚀
